# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
# Out:
# 2023-04-28 09:57:32.773930: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-04-28 09:57:32.773979: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# # Import the data

# %%
training = pd.read_csv("training over and under 3.csv")
test = pd.read_csv("val3.csv")

training = training[["Peruntukan","Pusat_kota","Visibilitas","Bangunan","Luas"]]
test = test[["Peruntukan","Pusat_kota","Visibilitas","Bangunan","Luas"]]

# %% [markdown]
# # Change categorical to number

# %%
condition = [  training.Pusat_kota == "Pusat",
             training.Pusat_kota == "Sedang",
              training.Pusat_kota == "Pinggir",
]

value = [3,2,1]

training.Pusat_kota = np.select(condition,value)
####
####

condition = [  training.Visibilitas == "Strategis",
             training.Visibilitas == "Sedang",
              training.Visibilitas == "Kurang",
]

value = [3,2,1]

training.Visibilitas = np.select(condition,value)
#####
#####

condition = [  training.Bangunan == "Bagus",
             training.Bangunan == "Sedang",
             
]

value = [2,1]

training.Bangunan = np.select(condition,value,0)


condition = [ 
            training.Peruntukan == "Pasar",
             training.Peruntukan == "Kantor",
             training.Peruntukan == "Ruko",
             training.Peruntukan == "Taman",
             training.Peruntukan == "Perumahan",
             training.Peruntukan == "Sawah",
             
]

value = [5,4,3,2,1,0]

training.Peruntukan = np.select(condition,value,0)

# %%
condition = [  test.Pusat_kota == "Pusat",
             test.Pusat_kota == "Sedang",
              test.Pusat_kota == "Pinggir",
]

value = [3,2,1]

test.Pusat_kota = np.select(condition,value)
####
####

condition = [  test.Visibilitas == "Strategis",
             test.Visibilitas == "Sedang",
              test.Visibilitas == "Kurang",
]

value = [3,2,1]

test.Visibilitas = np.select(condition,value)
#####
#####

condition = [  test.Bangunan == "Bagus",
             test.Bangunan == "Sedang",
             
]

value = [2,1]

test.Bangunan = np.select(condition,value,0)


condition = [ 
            test.Peruntukan == "Pasar",
             test.Peruntukan == "Kantor",
             test.Peruntukan == "Ruko",
             test.Peruntukan == "Taman",
             test.Peruntukan == "Perumahan",
             test.Peruntukan == "Sawah",
             
]

value = [5,4,3,2,1,0]

test.Peruntukan = np.select(condition,value,0)

# %%
training
# Out:
#      Peruntukan  Pusat_kota  Visibilitas  Bangunan   Luas
# 0             1           2            3         1  87580
# 1             1           2            3         1  87580
# 2             1           2            3         1  87580
# 3             1           2            3         1  87580
# 4             1           2            3         1  57945
# ..          ...         ...          ...       ...    ...
# 123           2           3            3         0   1624
# 124           2           3            3         0  17033
# 125           2           3            3         0   2074
# 126           2           3            3         0   1700
# 127           2           3            3         0   1624
#
# [128 rows x 5 columns]

# %%
test
# Out:
#     Peruntukan  Pusat_kota  Visibilitas  Bangunan   Luas
# 0            4           3            3         2   1192
# 1            4           3            2         2    997
# 2            5           3            3         2  14060
# 3            5           3            3         1   6025
# 4            0           1            1         0  10390
# 5            0           1            1         0   7745
# 6            0           1            1         0   5700
# 7            1           2            3         1  27024
# 8            1           1            2         1   8740
# 9            3           3            3         2   3614
# 10           3           3            3         2    754
# 11           3           3            2         1    599
# 12           2           3            3         0   1945

# %% [markdown]
# # Dataframe to Dataset

# %%
def df_to_dataset(dataframe, shuffle=True, batch_size=4):
  dataframe = dataframe.copy()
  labels = dataframe.pop('Peruntukan')
  ds = tf.data.Dataset.from_tensor_slices((dict(dataframe), labels))
  if shuffle:
    ds = ds.shuffle(buffer_size=len(dataframe))
  ds = ds.batch(batch_size)
  return ds

# %%
train_ds = df_to_dataset(training)
val_ds = df_to_dataset(test)
# Out:
# 2023-04-28 09:57:36.862178: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-04-28 09:57:36.862265: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-04-28 09:57:36.862319: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (gusanwa): /proc/driver/nvidia/version does not exist
# 2023-04-28 09:57:36.862895: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Feature Normalizer

# %%
def get_normalization_layer(name, dataset):
  # Create a Normalization layer for the feature.
  normalizer = layers.Normalization(axis=None)

  # Prepare a Dataset that only yields the feature.
  feature_ds = dataset.map(lambda x, y: x[name])

  # Learn the statistics of the data.
  normalizer.adapt(feature_ds)

  return normalizer

# %%
all_inputs = []
encoded_features = []

# Numerical features.
for header in ["Pusat_kota","Visibilitas","Bangunan","Luas"]:
  numeric_col = tf.keras.Input(shape=(1,), name=header)
  normalization_layer = get_normalization_layer(header, train_ds)
  encoded_numeric_col = normalization_layer(numeric_col)
  all_inputs.append(numeric_col)
  encoded_features.append(encoded_numeric_col)

# %% [markdown]
# # Model build

# %%
all_features = tf.keras.layers.concatenate(encoded_features)
x = tf.keras.layers.Dense(32, activation="relu")(all_features)
x = tf.keras.layers.Dropout(0.5)(x)
output = tf.keras.layers.Dense(6)(x)

model = tf.keras.Model(all_inputs, output)

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=["accuracy"])

# %%
# Use `rankdir='LR'` to make the graph horizontal.
tf.keras.utils.plot_model(model, show_shapes=True, rankdir="LR")
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
model.fit(train_ds, epochs=100, validation_data=val_ds)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 2s 17ms/step - loss: 1.8930 - accuracy: 0.2734 - val_loss: 1.7693 - val_accuracy: 0.3077
# Epoch 2/100
# 32/32 [==============================] - 0s 6ms/step - loss: 1.7818 - accuracy: 0.2578 - val_loss: 1.6365 - val_accuracy: 0.3846
# Epoch 3/100
# 32/32 [==============================] - 0s 6ms/step - loss: 1.6968 - accuracy: 0.3594 - val_loss: 1.4976 - val_accuracy: 0.6154
# Epoch 4/100
# 32/32 [==============================] - 0s 6ms/step - loss: 1.6247 - accuracy: 0.3750 - val_loss: 1.3984 - val_accuracy: 0.6923
# Epoch 5/100
# 32/32 [==============================] - 0s 5ms/step - loss: 1.5051 - accuracy: 0.4141 - val_loss: 1.3038 - val_accuracy: 0.6154
# Epoch 6/100
# 32/32 [==============================] - 0s 6ms/step - loss: 1.3749 - accuracy: 0.4531 - val_loss: 1.2139 - val_accuracy: 0.6154
# Epoch 7/100
# 32/32 [==============================] - 0s 5ms/step - loss: 1.3688 - accuracy: 0.4141 - val_loss: 1.1431 - val_accuracy: 0.7692
# Epoch 8/100
# 32/32 [==============================] - 0s 4ms/step - loss: 1.2770 - accuracy: 0.4922 - val_loss: 1.0792 - val_accuracy: 0.7692
# Epoch 9/100
# 32/32 [==============================] - 0s 5ms/step - loss: 1.1399 - accuracy: 0.6172 - val_loss: 1.0216 - val_accuracy: 0.7692
# Epoch 10/100
# 32/32 [==============================] - 0s 5ms/step - loss: 1.1910 - accuracy: 0.5469 - val_loss: 0.9713 - val_accuracy: 0.7692
# Epoch 11/100
# 32/32 [==============================] - 0s 6ms/step - loss: 1.1566 - accuracy: 0.5234 - val_loss: 0.9278 - val_accuracy: 0.7692
# Epoch 12/100
# 32/32 [==============================] - 0s 5ms/step - loss: 1.0508 - accuracy: 0.6172 - val_loss: 0.8864 - val_accuracy: 0.7692
# Epoch 13/100
# 32/32 [==============================] - 0s 4ms/step - loss: 1.0514 - accuracy: 0.6406 - val_loss: 0.8492 - val_accuracy: 0.7692
# Epoch 14/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.9702 - accuracy: 0.6953 - val_loss: 0.8156 - val_accuracy: 0.7692
# Epoch 15/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.9409 - accuracy: 0.7109 - val_loss: 0.7832 - val_accuracy: 0.7692
# Epoch 16/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.8928 - accuracy: 0.7266 - val_loss: 0.7508 - val_accuracy: 0.7692
# Epoch 17/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.9219 - accuracy: 0.6953 - val_loss: 0.7196 - val_accuracy: 0.8462
# Epoch 18/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.9111 - accuracy: 0.6797 - val_loss: 0.6947 - val_accuracy: 0.8462
# Epoch 19/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.8203 - accuracy: 0.7109 - val_loss: 0.6708 - val_accuracy: 0.8462
# Epoch 20/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.7906 - accuracy: 0.7422 - val_loss: 0.6487 - val_accuracy: 0.8462
# Epoch 21/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.7913 - accuracy: 0.7578 - val_loss: 0.6268 - val_accuracy: 0.8462
# Epoch 22/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.7590 - accuracy: 0.7578 - val_loss: 0.6063 - val_accuracy: 0.8462
# Epoch 23/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.7154 - accuracy: 0.7812 - val_loss: 0.5857 - val_accuracy: 0.8462
# Epoch 24/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.7012 - accuracy: 0.7500 - val_loss: 0.5684 - val_accuracy: 0.8462
# Epoch 25/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6920 - accuracy: 0.7891 - val_loss: 0.5506 - val_accuracy: 0.8462
# Epoch 26/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.7150 - accuracy: 0.7891 - val_loss: 0.5378 - val_accuracy: 0.8462
# Epoch 27/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6538 - accuracy: 0.8047 - val_loss: 0.5267 - val_accuracy: 0.8462
# Epoch 28/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.7579 - accuracy: 0.7266 - val_loss: 0.5120 - val_accuracy: 0.8462
# Epoch 29/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6493 - accuracy: 0.7969 - val_loss: 0.4925 - val_accuracy: 0.9231
# Epoch 30/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6494 - accuracy: 0.8125 - val_loss: 0.4818 - val_accuracy: 0.9231
# Epoch 31/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6288 - accuracy: 0.8047 - val_loss: 0.4724 - val_accuracy: 0.9231
# Epoch 32/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6072 - accuracy: 0.7891 - val_loss: 0.4618 - val_accuracy: 0.9231
# Epoch 33/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6502 - accuracy: 0.7734 - val_loss: 0.4543 - val_accuracy: 0.9231
# Epoch 34/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6355 - accuracy: 0.8047 - val_loss: 0.4451 - val_accuracy: 0.9231
# Epoch 35/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5949 - accuracy: 0.7891 - val_loss: 0.4307 - val_accuracy: 0.9231
# Epoch 36/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6171 - accuracy: 0.8359 - val_loss: 0.4253 - val_accuracy: 0.9231
# Epoch 37/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5876 - accuracy: 0.8047 - val_loss: 0.4173 - val_accuracy: 0.9231
# Epoch 38/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5817 - accuracy: 0.7969 - val_loss: 0.4107 - val_accuracy: 0.9231
# Epoch 39/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5584 - accuracy: 0.8125 - val_loss: 0.4057 - val_accuracy: 0.9231
# Epoch 40/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5699 - accuracy: 0.8203 - val_loss: 0.4012 - val_accuracy: 0.9231
# Epoch 41/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5158 - accuracy: 0.8281 - val_loss: 0.3882 - val_accuracy: 0.9231
# Epoch 42/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5367 - accuracy: 0.8438 - val_loss: 0.3828 - val_accuracy: 0.9231
# Epoch 43/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5119 - accuracy: 0.8438 - val_loss: 0.3770 - val_accuracy: 0.9231
# Epoch 44/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5697 - accuracy: 0.8438 - val_loss: 0.3697 - val_accuracy: 0.9231
# Epoch 45/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5116 - accuracy: 0.8359 - val_loss: 0.3655 - val_accuracy: 0.9231
# Epoch 46/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5306 - accuracy: 0.8203 - val_loss: 0.3561 - val_accuracy: 0.9231
# Epoch 47/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4935 - accuracy: 0.8203 - val_loss: 0.3549 - val_accuracy: 0.9231
# Epoch 48/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5490 - accuracy: 0.8438 - val_loss: 0.3544 - val_accuracy: 0.9231
# Epoch 49/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4505 - accuracy: 0.8438 - val_loss: 0.3445 - val_accuracy: 0.9231
# Epoch 50/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5372 - accuracy: 0.7812 - val_loss: 0.3370 - val_accuracy: 0.9231
# Epoch 51/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4704 - accuracy: 0.8594 - val_loss: 0.3361 - val_accuracy: 0.9231
# Epoch 52/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4145 - accuracy: 0.8750 - val_loss: 0.3335 - val_accuracy: 0.9231
# Epoch 53/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4396 - accuracy: 0.8516 - val_loss: 0.3288 - val_accuracy: 0.9231
# Epoch 54/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4666 - accuracy: 0.8359 - val_loss: 0.3225 - val_accuracy: 0.9231
# Epoch 55/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4624 - accuracy: 0.8516 - val_loss: 0.3244 - val_accuracy: 0.9231
# Epoch 56/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4403 - accuracy: 0.8828 - val_loss: 0.3159 - val_accuracy: 0.9231
# Epoch 57/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4671 - accuracy: 0.8125 - val_loss: 0.3131 - val_accuracy: 0.9231
# Epoch 58/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4396 - accuracy: 0.8750 - val_loss: 0.3076 - val_accuracy: 0.9231
# Epoch 59/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4213 - accuracy: 0.8594 - val_loss: 0.3067 - val_accuracy: 0.9231
# Epoch 60/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4039 - accuracy: 0.8750 - val_loss: 0.3019 - val_accuracy: 0.9231
# Epoch 61/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4917 - accuracy: 0.8359 - val_loss: 0.2989 - val_accuracy: 0.9231
# Epoch 62/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3824 - accuracy: 0.8828 - val_loss: 0.3018 - val_accuracy: 0.9231
# Epoch 63/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4740 - accuracy: 0.8359 - val_loss: 0.2970 - val_accuracy: 0.9231
# Epoch 64/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3425 - accuracy: 0.8906 - val_loss: 0.2930 - val_accuracy: 0.9231
# Epoch 65/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3882 - accuracy: 0.8594 - val_loss: 0.2859 - val_accuracy: 0.9231
# Epoch 66/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4745 - accuracy: 0.8516 - val_loss: 0.2828 - val_accuracy: 0.9231
# Epoch 67/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4317 - accuracy: 0.8516 - val_loss: 0.2810 - val_accuracy: 0.9231
# Epoch 68/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4335 - accuracy: 0.8594 - val_loss: 0.2835 - val_accuracy: 0.9231
# Epoch 69/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3618 - accuracy: 0.8750 - val_loss: 0.2773 - val_accuracy: 0.9231
# Epoch 70/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3839 - accuracy: 0.8516 - val_loss: 0.2762 - val_accuracy: 0.9231
# Epoch 71/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3700 - accuracy: 0.8672 - val_loss: 0.2720 - val_accuracy: 0.9231
# Epoch 72/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.4451 - accuracy: 0.8438 - val_loss: 0.2730 - val_accuracy: 0.9231
# Epoch 73/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3629 - accuracy: 0.8906 - val_loss: 0.2705 - val_accuracy: 0.9231
# Epoch 74/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4068 - accuracy: 0.8594 - val_loss: 0.2664 - val_accuracy: 0.9231
# Epoch 75/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3826 - accuracy: 0.8750 - val_loss: 0.2723 - val_accuracy: 0.9231
# Epoch 76/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3559 - accuracy: 0.8906 - val_loss: 0.2636 - val_accuracy: 0.9231
# Epoch 77/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3771 - accuracy: 0.8828 - val_loss: 0.2600 - val_accuracy: 0.9231
# Epoch 78/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3465 - accuracy: 0.9062 - val_loss: 0.2552 - val_accuracy: 0.9231
# Epoch 79/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3681 - accuracy: 0.8984 - val_loss: 0.2584 - val_accuracy: 0.9231
# Epoch 80/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3281 - accuracy: 0.9219 - val_loss: 0.2592 - val_accuracy: 0.9231
# Epoch 81/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3237 - accuracy: 0.9062 - val_loss: 0.2590 - val_accuracy: 0.9231
# Epoch 82/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3654 - accuracy: 0.8750 - val_loss: 0.2563 - val_accuracy: 0.9231
# Epoch 83/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3613 - accuracy: 0.9062 - val_loss: 0.2594 - val_accuracy: 0.9231
# Epoch 84/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3106 - accuracy: 0.8750 - val_loss: 0.2577 - val_accuracy: 0.9231
# Epoch 85/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3507 - accuracy: 0.8828 - val_loss: 0.2558 - val_accuracy: 0.9231
# Epoch 86/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3391 - accuracy: 0.8906 - val_loss: 0.2499 - val_accuracy: 0.9231
# Epoch 87/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3512 - accuracy: 0.8906 - val_loss: 0.2484 - val_accuracy: 0.9231
# Epoch 88/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3357 - accuracy: 0.8906 - val_loss: 0.2463 - val_accuracy: 0.9231
# Epoch 89/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3215 - accuracy: 0.8906 - val_loss: 0.2441 - val_accuracy: 0.9231
# Epoch 90/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3232 - accuracy: 0.8984 - val_loss: 0.2440 - val_accuracy: 0.9231
# Epoch 91/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3052 - accuracy: 0.9219 - val_loss: 0.2446 - val_accuracy: 0.9231
# Epoch 92/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3262 - accuracy: 0.8984 - val_loss: 0.2472 - val_accuracy: 0.9231
# Epoch 93/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3195 - accuracy: 0.8984 - val_loss: 0.2406 - val_accuracy: 0.9231
# Epoch 94/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2892 - accuracy: 0.9297 - val_loss: 0.2414 - val_accuracy: 0.9231
# Epoch 95/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.3192 - accuracy: 0.9141 - val_loss: 0.2350 - val_accuracy: 0.9231
# Epoch 96/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3219 - accuracy: 0.9141 - val_loss: 0.2380 - val_accuracy: 0.9231
# Epoch 97/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2579 - accuracy: 0.9219 - val_loss: 0.2337 - val_accuracy: 0.9231
# Epoch 98/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2878 - accuracy: 0.9219 - val_loss: 0.2315 - val_accuracy: 0.9231
# Epoch 99/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2924 - accuracy: 0.9297 - val_loss: 0.2329 - val_accuracy: 0.9231
# Epoch 100/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3081 - accuracy: 0.8906 - val_loss: 0.2310 - val_accuracy: 0.9231

# %%
model.predict(val_ds)
# Out:
# array([[ 7.62435293e+00,  1.26827288e+00, -6.93008184e+00,
#         -7.88345480e+00, -1.23001842e+01, -1.94982204e+01],
#        [-8.65041351e+00, -3.49776936e+00, -1.03316269e+01,
#          2.51760006e+00,  3.94394994e+00, -2.91831374e+00],
#        [-6.77848482e+00, -1.45123053e+00, -5.29345846e+00,
#          2.39492193e-01, -1.41322002e-01,  2.16307640e+00],
#        [ 7.69359350e+00,  1.33239603e+00, -6.86925983e+00,
#         -8.08726597e+00, -1.24110489e+01, -1.95265274e+01],
#        [-5.30129480e+00, -9.85980153e-01, -7.78749049e-01,
#         -1.17151156e-01, -2.95435429e+00,  2.34814596e+00],
#        [-2.36956644e+00,  2.93706656e+00, -2.63580704e+00,
#         -5.68903685e+00, -3.77140331e+00, -1.72559798e+00],
#        [-3.04618120e+00, -1.48600590e+00,  4.51485157e+00,
#         -5.57927036e+00, -9.70463467e+00, -3.38385820e+00],
#        [-4.11656809e+00, -1.05501795e+00, -4.51377439e+00,
#          2.05039024e+00, -1.95567012e+00, -3.47169185e+00],
#        [-8.85772610e+00, -3.41480780e+00, -7.78414488e+00,
#          2.70473075e+00,  1.42692733e+00, -4.99064028e-02],
#        [ 2.66325474e-03,  3.60594106e+00, -8.05560780e+00,
#         -5.13550043e+00, -1.76819873e+00, -7.27373695e+00],
#        [-9.39699459e+00, -3.86356759e+00, -8.33990383e+00,
#          3.25080323e+00,  1.70105124e+00, -5.29465675e-01],
#        [-9.50114155e+00, -3.94085813e+00, -8.43829536e+00,
#          3.32814479e+00,  1.73818898e+00, -6.07472658e-01],
#        [ 7.77066660e+00,  1.42752516e+00, -6.80461788e+00,
#         -8.37413502e+00, -1.25583658e+01, -1.95539722e+01]], dtype=float32)

# %%
import numpy as np

# Daftar label kelas
label_kelas = ['kantor', 'pasar', 'ruko', 'sawah', 'taman', 'perumahan']

# Lakukan prediksi pada data dan dapatkan output model
output_model = model.predict(data)

# Dapatkan nilai probabilitas untuk setiap kelas
probabilitas = model.predict_proba(data)

# Urutkan nilai probabilitas dari yang terbesar hingga terkecil
indeks_urutan = np.argsort(probabilitas)[::-1]

# Pilih tiga kelas dengan probabilitas tertinggi
tiga_kelas = [(label_kelas[i], probabilitas[i]) for i in indeks_urutan[:3]]

# Cetak tiga kelas dan nilai probabilitasnya
for kelas, nilai_probabilitas in tiga_kelas:
    print('{}: {:.2%}'.format(kelas, nilai_probabilitas))

# %%
folium.LayerControl().add_to(m)

m
folium.LayerControl().add_to(m)

m
import folium
import geopandas as gpd
from folium.plugins import MarkerCluster

m = folium.Map(location=[-7.6306, 111.5170], zoom_start=12, tiles='Stamen Terrain')

folium.Marker([-7.6232, 111.5240], popup='Alun-alun Kota Madiun').add_to(m)
folium.Marker([-7.6317, 111.5261], popup='Stasiun Madiun').add_to(m)
folium.Marker([-7.6372, 111.5182], popup='Terminal Tipe A Madiun').add_to(m)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker([-7.6232, 111.5240], popup='Alun-alun Kota Madiun').add_to(marker_cluster)
folium.Marker([-7.6317, 111.5261], popup='Stasiun Madiun').add_to(marker_cluster)
folium.Marker([-7.6372, 111.5182], popup='Terminal Tipe A Madiun').add_to(marker_cluster)

folium.LayerControl().add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f690f3cb2588511e7b4ab59c5025c8ec {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f690f3cb2588511e7b4ab59c5025c8ec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f690f3cb2588511e7b4ab59c5025c8ec = L.map(
#                 &quot;map_f690f3cb2588511e7b4ab59c5025c8ec&quot;,
#                 {
#                     center: [-7.6306, 111.517],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b7b51678c4db7a039cb4ce2ef53687e3 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f690f3cb2588511e7b4ab59c5025c8ec);
#
#
#             var marker_10534ee152d5bfd4bd8ef346a3b42ad0 = L.marker(
#                 [-7.6232, 111.524],
#                 {}
#             ).addTo(map_f690f3cb2588511e7b4ab59c5025c8ec);
#
#
#         var popup_b831c77d8f88c34bdb823bdcefc61daf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5efc1d6ef1a5a9a3eada66ee0d7a34a0 = $(`&lt;div id=&quot;html_5efc1d6ef1a5a9a3eada66ee0d7a34a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alun-alun Kota Madiun&lt;/div&gt;`)[0];
#                 popup_b831c77d8f88c34bdb823bdcefc61daf.setContent(html_5efc1d6ef1a5a9a3eada66ee0d7a34a0);
#
#
#
#         marker_10534ee152d5bfd4bd8ef346a3b42ad0.bindPopup(popup_b831c77d8f88c34bdb823bdcefc61daf)
#         ;
#
#
#
#
#             var marker_efb174245e337fb77c4fe4cccd6af729 = L.marker(
#                 [-7.6317, 111.5261],
#                 {}
#             ).addTo(map_f690f3cb2588511e7b4ab59c5025c8ec);
#
#
#         var popup_b9d376ac5ecd0cdad57a398a174b6115 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c4746057b732c3b58a26c21a0dc17149 = $(`&lt;div id=&quot;html_c4746057b732c3b58a26c21a0dc17149&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Stasiun Madiun&lt;/div&gt;`)[0];
#                 popup_b9d376ac5ecd0cdad57a398a174b6115.setContent(html_c4746057b732c3b58a26c21a0dc17149);
#
#
#
#         marker_efb174245e337fb77c4fe4cccd6af729.bindPopup(popup_b9d376ac5ecd0cdad57a398a174b6115)
#         ;
#
#
#
#
#             var marker_87e6453650fa2ba40fe18c7479213499 = L.marker(
#                 [-7.6372, 111.5182],
#                 {}
#             ).addTo(map_f690f3cb2588511e7b4ab59c5025c8ec);
#
#
#         var popup_6f711f125b83b9a62134d3ca6d725692 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_15e0849c4dc7f37b246a58fd74bf862c = $(`&lt;div id=&quot;html_15e0849c4dc7f37b246a58fd74bf862c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Terminal Tipe A Madiun&lt;/div&gt;`)[0];
#                 popup_6f711f125b83b9a62134d3ca6d725692.setContent(html_15e0849c4dc7f37b246a58fd74bf862c);
#
#
#
#         marker_87e6453650fa2ba40fe18c7479213499.bindPopup(popup_6f711f125b83b9a62134d3ca6d725692)
#         ;
#
#
#
#
#             var marker_cluster_9973ff4e21f0634d923bba73f4cdf0f4 = L.markerClusterGroup(
#                 {}
#             );
#             map_f690f3cb2588511e7b4ab59c5025c8ec.addLayer(marker_cluster_9973ff4e21f0634d923bba73f4cdf0f4);
#
#
#             var marker_c5400af78ea1944fc4370ec63ee067bc = L.marker(
#                 [-7.6232, 111.524],
#                 {}
#             ).addTo(marker_cluster_9973ff4e21f0634d923bba73f4cdf0f4);
#
#
#         var popup_a059c918abe251535f1151e82cf94aca = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_21fe080d4fe409f9ebd4f0bc6ea70c48 = $(`&lt;div id=&quot;html_21fe080d4fe409f9ebd4f0bc6ea70c48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alun-alun Kota Madiun&lt;/div&gt;`)[0];
#                 popup_a059c918abe251535f1151e82cf94aca.setContent(html_21fe080d4fe409f9ebd4f0bc6ea70c48);
#
#
#
#         marker_c5400af78ea1944fc4370ec63ee067bc.bindPopup
