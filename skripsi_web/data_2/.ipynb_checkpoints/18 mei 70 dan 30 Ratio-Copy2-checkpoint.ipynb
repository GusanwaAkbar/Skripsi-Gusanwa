# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
import matplotlib.pyplot as plt

import keras
import sklearn
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.callbacks import ModelCheckpoint
# Out:
# 2023-05-19 04:42:44.310263: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-05-19 04:42:44.310298: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# # Import the data

# %%
import pandas as pd
from sklearn.utils import shuffle

# Read the CSV file into a pandas DataFrame
data = pd.read_csv("rumus + data skripsi angka polos jarak dan visibilitas 2.csv")

# Shuffle the data
shuffled_data = shuffle(data, random_state=42)

# Calculate the split index based on the desired 50:50 ratio
split_index = int(len(shuffled_data) * 0.5)

# Split the data into two halves
data_1 = shuffled_data[:split_index]
data_2 = shuffled_data[split_index:]

# Verify the lengths of the split data
print(f"Data 1 length: {len(data_1)}")
print(f"Data 2 length: {len(data_2)}")
# Out:
# Data 1 length: 51
# Data 2 length: 52

# %%
import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split



# Shuffle the data
shuffled_data = shuffle(data, random_state=42)

# Get unique classes from the "Peruntukan" column
classes = shuffled_data['Peruntukan'].unique()

# Initialize empty dataframes for train and test data
train_data = pd.DataFrame()
test_data = pd.DataFrame()

# Iterate over each class
for cls in classes:
    cls_data = shuffled_data[shuffled_data['Peruntukan'] == cls]
    
    # Split the class data into train and test
    cls_train, cls_test = train_test_split(cls_data, test_size=0.3, random_state=42)
    
    # Append the train and test data to the respective dataframes
    train_data = train_data.append(cls_train)
    test_data = test_data.append(cls_test)

# Verify the lengths of the split data
print(f"Train data length: {len(train_data)}")
print(f"Test data length: {len(test_data)}")
# Out:
# /tmp/ipykernel_254455/1115530508.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(cls_train)
# /tmp/ipykernel_254455/1115530508.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data = test_data.append(cls_test)
# /tmp/ipykernel_254455/1115530508.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(cls_train)
# /tmp/ipykernel_254455/1115530508.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data = test_data.append(cls_test)
# /tmp/ipykernel_254455/1115530508.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(cls_train)
# /tmp/ipykernel_254455/1115530508.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data = test_data.append(cls_test)
# /tmp/ipykernel_254455/1115530508.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(cls_train)
# Train data length: 69
# Test data length: 34
# /tmp/ipykernel_254455/1115530508.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data = test_data.append(cls_test)
# /tmp/ipykernel_254455/1115530508.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(cls_train)
# /tmp/ipykernel_254455/1115530508.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data = test_data.append(cls_test)
# /tmp/ipykernel_254455/1115530508.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(cls_train)
# /tmp/ipykernel_254455/1115530508.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data = test_data.append(cls_test)

# %%
train_data
# Out:
#       No  Nama Aset Bentuk Pemanfaatan Peruntukan Pusat_kota Visibilitas  \
# 68  79.0        NaN               Sewa       Ruko      Pusat   Strategis
# 65  58.0        NaN              Pakai       Ruko      Pusat      Sedang
# 29  29.0        NaN               Sewa       Ruko      Pusat   Strategis
# 34  20.0        NaN              Pakai       Ruko      Pusat      Sedang
# 87  44.0        NaN              Pakai       Ruko      Pusat      Sedang
# ..   ...        ...                ...        ...        ...         ...
# 17  24.0        NaN               Sewa  Perumahan     Sedang      Kurang
# 20  28.0        NaN               Sewa  Perumahan     Sedang      Kurang
# 49  72.0        NaN              Pakai      Taman      Pusat   Strategis
# 73  70.0        NaN              Pakai      Taman      Pusat   Strategis
# 48  71.0        NaN              Pakai      Taman      Pusat   Strategis
#
#    Bangunan   Luas          Desa   Kecamatan  ...   Luas.1    Bujur  Lintang  \
# 68    Bagus    229       JOSENAN       TAMAN  ...    229.0  30952.0  39189.0
# 65   Sedang   1217    MADIUN LOR  MANGUHARJO  ...   1217.0  31360.0  37246.0
# 29    Bagus   3614        KLEGEN  KARTOHARJO  ...   3614.0  32404.0  37865.0
# 34   Sedang    421       KEJURON       TAMAN  ...    421.0  31444.0  37885.0
# 87   Sedang   3565  ORO ORO OMBO  KARTOHARJO  ...   3565.0  32109.0  37365.0
# 58    4.0        NaN              Pakai     Kantor      Pusat       Bagus
# 32   93.0        NaN              Pakai     Kantor    Pinggir      Sedang
# 6    64.0        NaN              Pakai      Sawah    Pinggir      Kurang
# 101   NaN        NaN              Pakai      Sawah    Pinggir      Kurang
# 10   68.0        NaN              Pakai      Sawah    Pinggir      Kurang
# 11   69.0        NaN              Pakai      Sawah    Pinggir      Kurang
# 96   94.0        NaN              Pakai      Sawah    Pinggir      Kurang
# 7    65.0        NaN              Pakai      Sawah    Pinggir      Kurang
# 97   95.0        NaN              Pakai      Sawah    Pinggir      Kurang
# 18   26.0        NaN               Sewa  Perumahan     Sedang      Kurang
# 19   27.0        NaN               Sewa  Perumahan     Sedang      Kurang
# 81   25.0        NaN               Sewa  Perumahan     Sedang      Kurang
# 16   73.0        NaN              Pakai      Taman      Pusat   Strategis
# 37   88.0        NaN              Pakai      Taman      Pusat   Strategis
#
#     Bangunan   Luas             Desa   Kecamatan  ...   Luas.1         Bujur  \
# 46     Bagus    865          PANDEAN       TAMAN  ...    865.0  31114.000000
# 64    Sedang   2235       KARTOHARJO  KARTOHARJO  ...   2235.0  31336.000000
# 22     Bagus    270       MADIUN LOR  MANGUHARJO  ...    270.0  31302.000000
# 70     Bagus   2379  NAMBANGAN KIDUL  MANGUHARJO  ...   2379.0  31053.000000
# 85     Bagus   2000              NaN         NaN  ...   2000.0    111.515217
# 86     Bagus     70              NaN         NaN  ...     70.0    111.661205
# 24     Bagus    754     ORO ORO OMBO  KARTOHARJO  ...    754.0  31782.000000
# 57    Sedang    380     ORO ORO OMBO  KARTOHARJO  ...    380.0  32117.000000
# 75    Sedang    175       MADIUN LOR  MANGUHARJO  ...    175.0  31286.000000
# 26     Bagus  87580           KLEGEN  KARTOHARJO  ...  87580.0  32516.000000
# 61    Sedang   4865        REJOMULYO  KARTOHARJO  ...   4865.0  32542.000000
# 55    Sedang   4105     ORO ORO OMBO  KARTOHARJO  ...   4105.0  32203.000000
# 43     Bagus   1150         MOJOREJO       TAMAN  ...   1150.0  31958.000000
# 50     Bagus   6025       KARTOHARJO  KARTOHARJO  ...   6025.0  31242.000000
# 52     Bagus  55157     ORO ORO OMBO  KARTOHARJO  ...  55157.0  32148.000000
# 67     Bagus    905        MANISREJO       TAMAN  ...    905.0  32800.000000
# 71     Bagus   1490         KANIGORO  KARTOHARJO  ...   1490.0  32892.000000
# 33     Bagus  15710          KEJURON       TAMAN  ...  15710.0  31278.000000
# 77     Bagus    200              NaN         NaN  ...    200.0    111.495008
# 62     Bagus    410         MOJOREJO       TAMAN  ...    410.0  32041.000000
# 58     Bagus   5070       KARTOHARJO  KARTOHARJO  ...   5070.0  31306.000000
# 32     Bagus    600         DEMANGAN       TAMAN  ...    600.0  31419.000000
# 6      Tidak   3176          SOGATEN  MANGUHARJO  ...   3176.0  31180.000000
# 101    Tidak  18110         SUKOSARI  KARTOHARJO  ...  18110.0  31977.000000
# 10     Tidak   2370          KEJURON       TAMAN  ...   2370.0  30312.000000
# 11     Tidak   6065          KEJURON       TAMAN  ...   6065.0  29877.000000
# 26      111.520149          7.624574              2811        2592.305034
# 61      111.520149          7.624574              2912        2459.839839
# 55      111.520149          7.624574              2308        1838.230938
# 43      111.520149          7.624574              1795        1656.318389
# 50      111.520149          7.624574               648          62.764532
# 52      111.520149          7.624574              2209        1736.810427
# 67      111.520149          7.624574              3661        3601.357402
# 71      111.520149          7.624574              3527        3310.271455
# 33      111.520149          7.624574               557         765.887686
# 77      111.520149          7.624574              2451        2770.869821
# 62      111.520149          7.624574              1938        1772.659281
# 58      111.520149          7.624574               721         181.231532
# 32      111.520149          7.624574              3647        4087.167893
# 6       111.520149          7.624574              3131        2614.434517
# 101     111.520149          7.624574              2615        1998.062583
# 10      111.520149          7.624574              1525        2119.585885
# 11      111.520149          7.624574              2225        2769.702392
# 96      111.520149          7.624574              3949        4169.365079
# 7       111.520149          7.624574              1725        1886.691962
# 97      111.520149          7.624574              3772        3982.014575
# 18      111.520149          7.624574              2536        2289.806804
# 19      111.520149          7.624574              5083        4495.038477
# 81      111.520149          7.624574              2265        2465.973567
# 16      111.520149          7.624574               598          36.933018
# 37      111.520149          7.624574              1248        1311.091484
#
# [34 rows x 23 columns]

# %%
training = train_data
test = test_data

training = training[["Peruntukan","Pusat_kota","Visibilitas","Bangunan","Luas"]]
test = test[["Peruntukan","Pusat_kota","Visibilitas","Bangunan","Luas"]]

# %% [markdown]
# # Data visualisasi

# %% [markdown]
# # Change categorical to number

# %%
condition = [  training.Pusat_kota == "Pusat",
             training.Pusat_kota == "Sedang",
              training.Pusat_kota == "Pinggir",
]

value = [3,2,1]

training.Pusat_kota = np.select(condition,value)
####
####

condition = [  training.Visibilitas == "Strategis",
             training.Visibilitas == "Sedang",
              training.Visibilitas == "Kurang",
]

value = [3,2,1]

training.Visibilitas = np.select(condition,value)
#####
#####

condition = [  training.Bangunan == "Bagus",
             training.Bangunan == "Sedang",
             
]

value = [2,1]

training.Bangunan = np.select(condition,value,0)


condition = [ 
            training.Peruntukan == "Pasar",
             training.Peruntukan == "Kantor",
             training.Peruntukan == "Ruko",
             training.Peruntukan == "Taman",
             training.Peruntukan == "Perumahan",
             training.Peruntukan == "Sawah",
             
]

value = [5,4,3,2,1,0]

training.Peruntukan = np.select(condition,value,0)
# Out:
# /tmp/ipykernel_254455/3571141091.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training.Pusat_kota = np.select(condition,value)
# /tmp/ipykernel_254455/3571141091.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training.Visibilitas = np.select(condition,value)
# /tmp/ipykernel_254455/3571141091.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training.Bangunan = np.select(condition,value,0)
# /tmp/ipykernel_254455/3571141091.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training.Peruntukan = np.select(condition,value,0)

# %%
condition = [  test.Pusat_kota == "Pusat",
             test.Pusat_kota == "Sedang",
              test.Pusat_kota == "Pinggir",
]

value = [3,2,1]

test.Pusat_kota = np.select(condition,value)
####
####

condition = [  test.Visibilitas == "Strategis",
             test.Visibilitas == "Sedang",
              test.Visibilitas == "Kurang",
]

value = [3,2,1]

test.Visibilitas = np.select(condition,value)
#####
#####

condition = [  test.Bangunan == "Bagus",
             test.Bangunan == "Sedang",
             
]

value = [2,1]

test.Bangunan = np.select(condition,value,0)


condition = [ 
            test.Peruntukan == "Pasar",
             test.Peruntukan == "Kantor",
             test.Peruntukan == "Ruko",
             test.Peruntukan == "Taman",
             test.Peruntukan == "Perumahan",
             test.Peruntukan == "Sawah",
             
]

value = [5,4,3,2,1,0]

test.Peruntukan = np.select(condition,value,0)
# Out:
# /tmp/ipykernel_254455/3734195063.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test.Pusat_kota = np.select(condition,value)
# /tmp/ipykernel_254455/3734195063.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test.Visibilitas = np.select(condition,value)
# /tmp/ipykernel_254455/3734195063.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test.Bangunan = np.select(condition,value,0)
# /tmp/ipykernel_254455/3734195063.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test.Peruntukan = np.select(condition,value,0)

# %%
training
# Out:
#     Peruntukan  Pusat_kota  Visibilitas  Bangunan   Luas
# 68           3           3            3         2    229
# 65           3           3            2         1   1217
# 29           3           3            3         2   3614
# 34           3           3            2         1    421
# 87           3           3            2         1   3565
# ..         ...         ...          ...       ...    ...
# 17           1           2            1         1  27024
# 20           1           2            1         1  16590
# 49           2           3            3         0   1624
# 73           2           3            3         0   1945
# 48           2           3            3         0   1700
#
# [69 rows x 5 columns]

# %%
test
# Out:
#      Peruntukan  Pusat_kota  Visibilitas  Bangunan   Luas
# 46            3           3            3         2    865
# 64            3           3            3         1   2235
# 22            3           3            3         2    270
# 70            3           3            3         2   2379
# 85            3           3            3         2   2000
# 86            3           3            3         2     70
# 24            3           3            3         2    754
# 57            3           3            2         1    380
# 75            3           3            2         1    175
# 26            3           3            3         2  87580
# 61            3           3            2         1   4865
# 55            3           3            2         1   4105
# 43            3           3            3         2   1150
# 50            5           3            3         2   6025
# 52            5           3            3         2  55157
# 67            5           3            3         2    905
# 71            5           3            3         2   1490
# 33            5           3            3         2  15710
# 77            4           1            2         2    200
# 62            4           1            2         2    410
# 58            4           3            0         2   5070
# 32            4           1            2         2    600
# 6             0           1            1         0   3176
# 101           0           1            1         0  18110
# 10            0           1            1         0   2370
# 11            0           1            1         0   6065
# 96            0           1            1         0  10390
# 7             0           1            1         0   5720
# 97            0           1            1         0   6650
# 18            1           2            1         1  87580
# 19            1           2            1         1  57945
# 81            1           2            1         1   5055
# 16            2           3            3         0   2074
# 37            2           3            3         0  17033

# %% [markdown]
# # Dataframe to Dataset

# %%
def df_to_dataset(dataframe, shuffle=False, batch_size=4):
  dataframe = dataframe.copy()
  labels = dataframe.pop('Peruntukan')
  ds = tf.data.Dataset.from_tensor_slices((dict(dataframe), labels))
  if shuffle:
    ds = ds.shuffle(buffer_size=len(dataframe))
  ds = ds.batch(batch_size)
  return ds

# %%
train_ds = df_to_dataset(training)
val_ds = df_to_dataset(test)
# Out:
# 2023-05-19 04:42:54.392517: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-05-19 04:42:54.392593: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-05-19 04:42:54.392645: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (gusanwa): /proc/driver/nvidia/version does not exist
# 2023-05-19 04:42:54.393365: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Feature Normalizer

# %%
def get_normalization_layer(name, dataset):
  # Create a Normalization layer for the feature.
  normalizer = layers.Normalization(axis=None)

  # Prepare a Dataset that only yields the feature.
  feature_ds = dataset.map(lambda x, y: x[name])

  # Learn the statistics of the data.
  normalizer.adapt(feature_ds)

  return normalizer

# %%
all_inputs = []
encoded_features = []

# Numerical features.
for header in ["Pusat_kota","Visibilitas","Bangunan","Luas"]:
  numeric_col = tf.keras.Input(shape=(1,), name=header)
  normalization_layer = get_normalization_layer(header, train_ds)
  encoded_numeric_col = normalization_layer(numeric_col)
  all_inputs.append(numeric_col)
  encoded_features.append(encoded_numeric_col)

# %%
METRICS = [
      keras.metrics.TruePositives(name='tp'),
      keras.metrics.FalsePositives(name='fp'),
      keras.metrics.TrueNegatives(name='tn'),
      keras.metrics.FalseNegatives(name='fn'), 
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.AUC(name='auc'),
      keras.metrics.AUC(name='prc', curve='PR'), # precision-recall curve
]

def make_model(metrics=METRICS, output_bias=None):
  if output_bias is not None:
    output_bias = tf.keras.initializers.Constant(output_bias)
  model = keras.Sequential([
      keras.layers.Dense(
          16, activation='relu',
          input_shape=(train_features.shape[-1],)),
      keras.layers.Dropout(0.5),
      keras.layers.Dense(1, activation='sigmoid',
                         bias_initializer=output_bias),
  ])

# %%
checkpoint_callback = ModelCheckpoint("best_model 70 dan 30.h5", monitor='val_accuracy', save_best_only=True, mode='max')

# %% [markdown]
# # Model build

# %%
all_features = tf.keras.layers.concatenate(encoded_features)
x = tf.keras.layers.Dense(32, activation="relu")(all_features)
x = tf.keras.layers.Dropout(0.5)(x)
output = tf.keras.layers.Dense(6)(x)

model = tf.keras.Model(all_inputs, output)

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics="accuracy",
             )

# %%
# Use `rankdir='LR'` to make the graph horizontal.
tf.keras.utils.plot_model(model, show_shapes=True, rankdir="LR")

# %% [markdown]
# # Model Evaluation

# %%
import matplotlib.pyplot as plt


history = model.fit(train_ds, epochs=150, validation_data=val_ds, callbacks=[checkpoint_callback])

# Get the training and validation metrics from the history
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Plot accuracy
plt.plot(train_accuracy, label='Training Accuracy')
plt.plot(val_accuracy, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot loss
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/150
# 18/18 [==============================] - 1s 21ms/step - loss: 1.9158 - accuracy: 0.1159 - val_loss: 1.9781 - val_accuracy: 0.0588
# Epoch 2/150
# 18/18 [==============================] - 0s 7ms/step - loss: 1.8098 - accuracy: 0.1739 - val_loss: 1.8888 - val_accuracy: 0.1176
# Epoch 3/150
# 18/18 [==============================] - 0s 10ms/step - loss: 1.6611 - accuracy: 0.2754 - val_loss: 1.7995 - val_accuracy: 0.1471
# Epoch 4/150
# 18/18 [==============================] - 0s 9ms/step - loss: 1.5782 - accuracy: 0.2609 - val_loss: 1.7187 - val_accuracy: 0.3529
# Epoch 5/150
# 18/18 [==============================] - 0s 10ms/step - loss: 1.5520 - accuracy: 0.3188 - val_loss: 1.6496 - val_accuracy: 0.5882
# Epoch 6/150
# 18/18 [==============================] - 0s 12ms/step - loss: 1.4220 - accuracy: 0.3913 - val_loss: 1.5871 - val_accuracy: 0.6176
# Epoch 7/150
# 18/18 [==============================] - 0s 7ms/step - loss: 1.4328 - accuracy: 0.4348 - val_loss: 1.5328 - val_accuracy: 0.5882
# Epoch 8/150
# 18/18 [==============================] - 0s 7ms/step - loss: 1.3698 - accuracy: 0.4638 - val_loss: 1.4779 - val_accuracy: 0.6471
# Epoch 9/150
# 18/18 [==============================] - 0s 6ms/step - loss: 1.2576 - accuracy: 0.6377 - val_loss: 1.4245 - val_accuracy: 0.6471
# Epoch 10/150
# 18/18 [==============================] - 0s 7ms/step - loss: 1.2816 - accuracy: 0.5797 - val_loss: 1.3753 - val_accuracy: 0.6765
# Epoch 11/150
# 18/18 [==============================] - 0s 5ms/step - loss: 1.1743 - accuracy: 0.6377 - val_loss: 1.3349 - val_accuracy: 0.6765
# Epoch 12/150
# 18/18 [==============================] - 0s 5ms/step - loss: 1.1945 - accuracy: 0.6087 - val_loss: 1.3026 - val_accuracy: 0.6765
# Epoch 13/150
# 18/18 [==============================] - 0s 4ms/step - loss: 1.1163 - accuracy: 0.7391 - val_loss: 1.2715 - val_accuracy: 0.6765
# Epoch 14/150
# 18/18 [==============================] - 0s 4ms/step - loss: 1.1358 - accuracy: 0.6377 - val_loss: 1.2378 - val_accuracy: 0.6765
# Epoch 15/150
# 18/18 [==============================] - 0s 4ms/step - loss: 1.0868 - accuracy: 0.6957 - val_loss: 1.2046 - val_accuracy: 0.6471
# Epoch 16/150
# 18/18 [==============================] - 0s 4ms/step - loss: 1.0110 - accuracy: 0.7101 - val_loss: 1.1740 - val_accuracy: 0.6471
# Epoch 17/150
# 18/18 [==============================] - 0s 5ms/step - loss: 0.9698 - accuracy: 0.7391 - val_loss: 1.1515 - val_accuracy: 0.6471
# Epoch 18/150
# 18/18 [==============================] - 0s 6ms/step - loss: 0.9599 - accuracy: 0.7391 - val_loss: 1.1274 - val_accuracy: 0.6471
# Epoch 19/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.9382 - accuracy: 0.7246 - val_loss: 1.0923 - val_accuracy: 0.6471
# Epoch 20/150
# 18/18 [==============================] - 0s 4ms/step - loss: 1.0113 - accuracy: 0.7391 - val_loss: 1.0625 - val_accuracy: 0.6765
# Epoch 21/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.8905 - accuracy: 0.7536 - val_loss: 1.0325 - val_accuracy: 0.6765
# Epoch 22/150
# 18/18 [==============================] - 0s 7ms/step - loss: 0.8951 - accuracy: 0.7246 - val_loss: 1.0013 - val_accuracy: 0.7059
# Epoch 23/150
# 18/18 [==============================] - 0s 5ms/step - loss: 0.9963 - accuracy: 0.6957 - val_loss: 0.9721 - val_accuracy: 0.7059
# Epoch 24/150
# 18/18 [==============================] - 0s 5ms/step - loss: 0.8809 - accuracy: 0.7681 - val_loss: 0.9528 - val_accuracy: 0.7059
# Epoch 25/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.8869 - accuracy: 0.7101 - val_loss: 0.9421 - val_accuracy: 0.7059
# Epoch 26/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.8347 - accuracy: 0.7391 - val_loss: 0.9224 - val_accuracy: 0.7059
# Epoch 27/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.8609 - accuracy: 0.7536 - val_loss: 0.9015 - val_accuracy: 0.7059
# Epoch 28/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.8290 - accuracy: 0.7681 - val_loss: 0.8771 - val_accuracy: 0.6765
# Epoch 29/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.8011 - accuracy: 0.7681 - val_loss: 0.8557 - val_accuracy: 0.7059
# Epoch 30/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.8142 - accuracy: 0.7391 - val_loss: 0.8380 - val_accuracy: 0.7059
# Epoch 31/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.8032 - accuracy: 0.7681 - val_loss: 0.8262 - val_accuracy: 0.6765
# Epoch 32/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.7527 - accuracy: 0.7391 - val_loss: 0.8131 - val_accuracy: 0.6765
# Epoch 33/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.7769 - accuracy: 0.7681 - val_loss: 0.7990 - val_accuracy: 0.7059
# Epoch 34/150
# 18/18 [==============================] - 0s 5ms/step - loss: 0.7605 - accuracy: 0.7971 - val_loss: 0.7918 - val_accuracy: 0.7059
# Epoch 35/150
# 18/18 [==============================] - 0s 5ms/step - loss: 0.7463 - accuracy: 0.7826 - val_loss: 0.7786 - val_accuracy: 0.7059
# Epoch 36/150
# 18/18 [==============================] - 0s 6ms/step - loss: 0.7807 - accuracy: 0.7536 - val_loss: 0.7721 - val_accuracy: 0.7353
# Epoch 37/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6293 - accuracy: 0.8261 - val_loss: 0.7623 - val_accuracy: 0.7353
# Epoch 38/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.7030 - accuracy: 0.8116 - val_loss: 0.7484 - val_accuracy: 0.7353
# Epoch 39/150
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6725 - accuracy: 0.7391 - val_loss: 0.7363 - val_accuracy: 0.7353
# Epoch 40/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6421 - accuracy: 0.7681 - val_loss: 0.7253 - val_accuracy: 0.7353
# Epoch 41/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6304 - accuracy: 0.7536 - val_loss: 0.7119 - val_accuracy: 0.7353
# Epoch 42/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6231 - accuracy: 0.7826 - val_loss: 0.6987 - val_accuracy: 0.7353
# Epoch 43/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6441 - accuracy: 0.7681 - val_loss: 0.6894 - val_accuracy: 0.7353
# Epoch 44/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6368 - accuracy: 0.7971 - val_loss: 0.6795 - val_accuracy: 0.7353
# Epoch 45/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5892 - accuracy: 0.7681 - val_loss: 0.6635 - val_accuracy: 0.7353
# Epoch 46/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5868 - accuracy: 0.8261 - val_loss: 0.6470 - val_accuracy: 0.7353
# Epoch 47/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6567 - accuracy: 0.8116 - val_loss: 0.6326 - val_accuracy: 0.7353
# Epoch 48/150
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5943 - accuracy: 0.7536 - val_loss: 0.6260 - val_accuracy: 0.7353
# Epoch 49/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5988 - accuracy: 0.8551 - val_loss: 0.6210 - val_accuracy: 0.7353
# Epoch 50/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5925 - accuracy: 0.7971 - val_loss: 0.6156 - val_accuracy: 0.7353
# Epoch 51/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6070 - accuracy: 0.8116 - val_loss: 0.6114 - val_accuracy: 0.7353
# Epoch 52/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5910 - accuracy: 0.7391 - val_loss: 0.6082 - val_accuracy: 0.7353
# Epoch 53/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6073 - accuracy: 0.8116 - val_loss: 0.6049 - val_accuracy: 0.7353
# Epoch 54/150
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6193 - accuracy: 0.7101 - val_loss: 0.6042 - val_accuracy: 0.7353
# Epoch 55/150
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5341 - accuracy: 0.8261 - val_loss: 0.5937 - val_accuracy: 0.7353
# Epoch 56/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5432 - accuracy: 0.8261 - val_loss: 0.5913 - val_accuracy: 0.7353
# Epoch 57/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5453 - accuracy: 0.8116 - val_loss: 0.5899 - val_accuracy: 0.7353
# Epoch 58/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5923 - accuracy: 0.8116 - val_loss: 0.5897 - val_accuracy: 0.7353
# Epoch 59/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5548 - accuracy: 0.7971 - val_loss: 0.5904 - val_accuracy: 0.7353
# Epoch 60/150
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4997 - accuracy: 0.8406 - val_loss: 0.5821 - val_accuracy: 0.7353
# Epoch 61/150
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4970 - accuracy: 0.8261 - val_loss: 0.5727 - val_accuracy: 0.7353
# Epoch 62/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5372 - accuracy: 0.8116 - val_loss: 0.5609 - val_accuracy: 0.7353
# Epoch 63/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5062 - accuracy: 0.7971 - val_loss: 0.5488 - val_accuracy: 0.7353
# Epoch 64/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4257 - accuracy: 0.8116 - val_loss: 0.5378 - val_accuracy: 0.7353
# Epoch 65/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5151 - accuracy: 0.8261 - val_loss: 0.5252 - val_accuracy: 0.7353
# Epoch 66/150
# 18/18 [==============================] - 0s 5ms/step - loss: 0.
150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3995 - accuracy: 0.8406 - val_loss: 0.3943 - val_accuracy: 0.8824
# Epoch 128/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4065 - accuracy: 0.8841 - val_loss: 0.3927 - val_accuracy: 0.8824
# Epoch 129/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3626 - accuracy: 0.8116 - val_loss: 0.3925 - val_accuracy: 0.8824
# Epoch 130/150
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3595 - accuracy: 0.8406 - val_loss: 0.3895 - val_accuracy: 0.8824
# Epoch 131/150
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3498 - accuracy: 0.8841 - val_loss: 0.3896 - val_accuracy: 0.8824
# Epoch 132/150
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3496 - accuracy: 0.8406 - val_loss: 0.3884 - val_accuracy: 0.8824
# Epoch 133/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4400 - accuracy: 0.7971 - val_loss: 0.3864 - val_accuracy: 0.8824
# Epoch 134/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3473 - accuracy: 0.8841 - val_loss: 0.3837 - val_accuracy: 0.8824
# Epoch 135/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3884 - accuracy: 0.8551 - val_loss: 0.3809 - val_accuracy: 0.8824
# Epoch 136/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3234 - accuracy: 0.8406 - val_loss: 0.3806 - val_accuracy: 0.8824
# Epoch 137/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3466 - accuracy: 0.8551 - val_loss: 0.3805 - val_accuracy: 0.8824
# Epoch 138/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4027 - accuracy: 0.7971 - val_loss: 0.3795 - val_accuracy: 0.8824
# Epoch 139/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3194 - accuracy: 0.9130 - val_loss: 0.3796 - val_accuracy: 0.8824
# Epoch 140/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.2784 - accuracy: 0.9420 - val_loss: 0.3764 - val_accuracy: 0.8824
# Epoch 141/150
# 18/18 [==============================] - 0s 6ms/step - loss: 0.3647 - accuracy: 0.8841 - val_loss: 0.3736 - val_accuracy: 0.9118
# Epoch 142/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3647 - accuracy: 0.8261 - val_loss: 0.3705 - val_accuracy: 0.9118
# Epoch 143/150
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3092 - accuracy: 0.9275 - val_loss: 0.3702 - val_accuracy: 0.9118
# Epoch 144/150
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3150 - accuracy: 0.8696 - val_loss: 0.3717 - val_accuracy: 0.9118
# Epoch 145/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3377 - accuracy: 0.8406 - val_loss: 0.3729 - val_accuracy: 0.9118
# Epoch 146/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3234 - accuracy: 0.8696 - val_loss: 0.3725 - val_accuracy: 0.9118
# Epoch 147/150
# 18/18 [==============================] - 0s 4ms/step - loss: 0.3232 - accuracy: 0.8696 - val_loss: 0.3712 - val_accuracy: 0.9118
# Epoch 148/150
# 18/18 [==============================] - 0s 5ms/step - loss: 0.3650 - accuracy: 0.8116 - val_loss: 0.3676 - val_accuracy: 0.9118
# Epoch 149/150
# 18/18 [==============================] - 0s 6ms/step - loss: 0.3151 - accuracy: 0.8841 - val_loss: 0.3681 - val_accuracy: 0.9118
# Epoch 150/150
# 18/18 [==============================] - 0s 8ms/step - loss: 0.3510 - accuracy: 0.8551 - val_loss: 0.3680 - val_accuracy: 0.9118

# %%
max_test_accuracy_index = history.history['val_accuracy'].index(max(history.history['val_accuracy']))

# Get the corresponding training accuracy
training_accuracy = history.history['accuracy'][max_test_accuracy_index]

print('Best validation accuracy:', max(history.history['val_accuracy']))
print('Training accuracy at the best test accuracy:', training_accuracy)
# Out:
# Best validation accuracy: 0.9117646813392639
# Training accuracy at the best test accuracy: 0.8840579986572266

# %% [markdown]
# # Confusion Matriks

# %%
from sklearn.metrics import confusion_matrix
best_model = tf.keras.models.load_model('./best_model 70 dan 30.h5')
model = best_model

y_pred = model.predict(val_ds)

# Ubah output prediksi menjadi label kelas
label_kelas = ['Sawah', 'Perumahan', 'Taman', 'Ruko', 'Kantor', 'Pasar']
y_pred_label = [label_kelas[np.argmax(prediksi)] for prediksi in y_pred]

#test label
test_labels = test_data.Peruntukan

# Calculate the confusion matrix
cm = confusion_matrix(test_labels, y_pred_label)

print('Best validation accuracy:', max(history.history['val_accuracy']))
print('Training accuracy at the best test accuracy:', training_accuracy)
print('Confusion matrix:')
print(cm)
# Out:
# Best validation accuracy: 0.9117646813392639
# Training accuracy at the best test accuracy: 0.8840579986572266
# Confusion matrix:
# [[ 4  0  0  0  0  0]
#  [ 0  3  0  2  0  0]
#  [ 0  0  3  0  0  0]
#  [ 0  1  0 12  0  0]
#  [ 0  0  0  0  7  0]
#  [ 0  0  0  0  0  2]]

# %%
confusion_matrix = cm

true_positives = np.diagonal(confusion_matrix)

# Step 3: Calculate the accuracy percentage for each class
class_totals = np.sum(confusion_matrix, axis=1)
class_accuracies = true_positives / class_totals * 100

# Step 4: Calculate the overall accuracy percentage
total_instances = np.sum(confusion_matrix)
overall_accuracy = np.sum(true_positives) / total_instances * 100

# Step 5: Calculate the total data instances for each class
class_data_totals = np.sum(confusion_matrix, axis=0)

# Print the results
print("True Positives for each class:", true_positives)
print("Total Data Instances for each class:", class_data_totals)
print("Overall Accuracy Percentage:", overall_accuracy)
# Out:
# True Positives for each class: [ 4  3  3 12  7  2]
# Total Data Instances for each class: [ 4  4  3 14  7  2]
# Overall Accuracy Percentage: 91.17647058823529

# %%
true_positives = np.diagonal(confusion_matrix)

# Step 3: Calculate the accuracy percentage for each class
class_data_totals = np.sum(confusion_matrix, axis=0)
class_accuracies = true_positives / class_data_totals * 100

# Step 4: Calculate the overall accuracy percentage
total_instances = np.sum(confusion_matrix)
overall_accuracy = np.sum(true_positives) / total_instances * 100

# Print the results
print("Accuracy for each label:", class_accuracies)
print("True Positives for each class:", true_positives)
print("Total Data Instances for each class:", class_data_totals)
print("Overall Accuracy Percentage:", overall_accuracy)
# Out:
# Accuracy for each label: [100.          75.         100.          85.71428571 100.
#  100.        ]
# True Positives for each class: [ 4  3  3 12  7  2]
# Total Data Instances for each class: [ 4  4  3 14  7  2]
# Overall Accuracy Percentage: 91.17647058823529

# %%
for label, accuracy in zip(label_kelas, class_accuracies):
    print("Accuracy for", label, ":", accuracy)
# Out:
# Accuracy for Sawah : 100.0
# Accuracy for Perumahan : 75.0
# Accuracy for Taman : 100.0
# Accuracy for Ruko : 85.71428571428571
# Accuracy for Kantor : 100.0
# Accuracy for Pasar : 100.0

# %%
true_positives = np.diagonal(confusion_matrix)
false_positives = np.sum(confusion_matrix, axis=0) - true_positives
false_negatives = np.sum(confusion_matrix, axis=1) - true_positives

# Step 3: Calculate precision, recall, and F1 score for each label
accuracy = true_positives / np.sum(confusion_matrix, axis=1)
precision = true_positives / (true_positives + false_positives)
recall = true_positives / (true_positives + false_negatives)
f1_score = 2 * (precision * recall) / (precision + recall)

# Step 4: Calculate the total accuracy
total_accuracy = np.sum(true_positives) / np.sum(confusion_matrix) * 100

# Print the results
print("Accuracy for each label:", class_accuracies)
print("Precision for each label:", precision)
print("Recall for each label:", recall)
print("F1 Score for each label:", f1_score)
print("Total Accuracy:", total_accuracy)
# Out:
# Accuracy for each label: [100.          75.         100.          85.71428571 100.
#  100.        ]
# Precision for each label: [1.         0.75       1.         0.85714286 1.         1.        ]
# Recall for each label: [1.         0.6        1.         0.92307692 1.         1.        ]
# F1 Score for each label: [1.         0.66666667 1.         0.88888889 1.         1.        ]
# Total Accuracy: 91.17647058823529

# %%
true_positives = np.diagonal(confusion_matrix)
false_positives = np.sum(confusion_matrix, axis=0) - true_positives
false_negatives = np.sum(confusion_matrix, axis=1) - true_positives

# Step 3: Calculate precision, recall, and F1 score for each label
precision = true_positives / (true_positives + false_positives)
recall = true_positives / (true_positives + false_negatives)
f1_score = 2 * (precision * recall) / (precision + recall)

# Step 4: Calculate the total accuracy
total_accuracy = np.sum(true_positives) / np.sum(confusion_matrix) * 100

# Print the results
print("True Positives for each label:", true_positives)
print("total classes",class_data_totals)
print("tp+fp pembagi precision",true_positives + false_positives )
print("tp+fn pembagi recall",true_positives + false_negatives )
print("f1 p kali r", (precision * recall))
# Out:
# True Positives for each label: [ 4  3  3 12  7  2]
# total classes [ 4  4  3 14  7  2]
# tp+fp pembagi precision [ 4  4  3 14  7  2]
# tp+fn pembagi recall [ 4  5  3 13  7  2]
# f1 p kali r [1.         0.45       1.         0.79120879 1.         1.        ]

# %%
max_test_accuracy_index = history.history['val_accuracy'].index(max(history.history['val_accuracy']))

# Get the corresponding training accuracy
training_accuracy = history.history['accuracy'][max_test_accuracy_index]

print('Best validation accuracy:', max(history.history['val_accuracy']))
print('Training accuracy at the best test accuracy:', training_accuracy)
# Out:
# Best validation accuracy: 0.9117646813392639
# Training accuracy at the best test accuracy: 0.8840579986572266

# %%
model.predict(val_ds)
# Out:
# array([[ -6.170356  ,  -6.6026406 ,  -4.0836926 ,   2.5129862 ,
#          -3.4265015 ,   1.5201592 ],
#        [ -5.040804  ,  -5.6711435 ,  -0.7012763 ,   1.9127867 ,
#          -5.1664186 ,  -0.87973034],
#        [ -6.245297  ,  -6.809353  ,  -4.1011806 ,   2.5699062 ,
#          -3.358107  ,   1.3658398 ],
#        [ -5.964391  ,  -6.1752987 ,  -4.0602484 ,   2.3211222 ,
#          -3.5524652 ,   1.8369466 ],
#        [ -6.0154324 ,  -6.2779884 ,  -4.0661225 ,   2.3721662 ,
#          -3.5218713 ,   1.7621956 ],
#        [ -6.270488  ,  -6.8788357 ,  -4.1070585 ,   2.5890388 ,
#          -3.3351173 ,   1.3139676 ],
#        [ -6.1843367 ,  -6.641203  ,  -4.086955  ,   2.5236053 ,
#          -3.4137423 ,   1.4913703 ],
#        [ -3.734487  ,  -4.9783363 ,  -1.0361936 ,   2.282444  ,
#          -2.9204946 ,  -1.5747201 ],
#        [ -3.7557874 ,  -5.0598125 ,  -1.046736  ,   2.266955  ,
#          -2.9073663 ,  -1.6236441 ],
#        [ -8.207413  ,  -5.289465  , -19.333277  ,  -0.15548074,
#         -18.820496  ,   5.740004  ],
#        [ -3.1032982 ,  -3.590541  ,  -1.0823898 ,   2.235108  ,
#          -3.2773287 ,  -0.81796515],
#        [ -3.221111  ,  -3.8198833 ,  -1.0463555 ,   2.251553  ,
#          -3.182736  ,  -0.90971494],
#        [ -6.133031  ,  -6.5085497 ,  -4.0768857 ,   2.4839225 ,
#          -3.4562147 ,   1.590996  ],
#        [ -5.497711  ,  -5.2687597 ,  -3.997436  ,   1.8365762 ,
#          -3.8101158 ,   2.4473774 ],
#        [ -6.684995  ,  -4.7900267 , -13.027074  ,   1.0484134 ,
#         -11.588655  ,   4.776993  ],
#        [ -6.1653175 ,  -6.5887437 ,  -4.082517  ,   2.50916   ,
#          -3.4310994 ,   1.5305339 ],
#        [ -6.084116  ,  -6.416172  ,  -4.074027  ,   2.4408536 ,
#          -3.4807029 ,   1.6616071 ],
#        [ -4.844545  ,  -4.3987684 ,  -5.4880657 ,   1.5086125 ,
#          -4.5566883 ,   2.9960878 ],
#        [ -1.8127067 ,  -3.5173695 ,  -5.117794  ,  -2.8856425 ,
#           3.7268913 ,  -1.7398533 ],
#        [ -1.8065253 ,  -3.4596334 ,  -5.093666  ,  -2.883654  ,
#           3.7073295 ,  -1.725398  ],
#        [ -2.4802222 ,  -0.23914269,  -5.1130624 ,  -3.3440938 ,
#           1.2749428 ,  -2.9277773 ],
#        [ -1.8009322 ,  -3.4073956 ,  -5.071836  ,  -2.8818555 ,
#           3.6896305 ,  -1.7123191 ],
#        [  4.205394  ,  -2.3631883 ,  -2.9542215 ,  -8.279393  ,
#          -5.150969  ,  -6.338446  ],
#        [  4.377611  ,   0.6289182 ,  -4.648347  ,  -7.8268967 ,
#          -7.3412385 ,  -5.826607  ],
#        [  4.12768   ,  -2.7138603 ,  -2.9770088 ,  -8.291442  ,
#          -4.9224353 ,  -6.4424095 ],
#        [  4.379246  ,  -1.2347128 ,  -2.9835477 ,  -8.251963  ,
#          -5.8195415 ,  -5.9402227 ],
#        [  4.337919  ,  -0.35161707,  -3.4873817 ,  -8.018976  ,
#          -6.5055375 ,  -5.758626  ],
#        [  4.361499  ,  -1.3661151 ,  -2.975227  ,  -8.2526455 ,
#          -5.7448545 ,  -5.9886556 ],
#        [  4.3909473 ,  -1.0805409 ,  -3.013743  ,  -8.230163  ,
#          -5.9257164 ,  -5.907989  ],
#        [ -1.793741  ,   1.040507  , -18.511053  ,  -6.709225  ,
#         -17.752306  ,  -1.2439113 ],
#        [ -0.57282454,   1.6056272 , -12.635883  ,  -5.3017735 ,
#         -11.029435  ,  -2.0761087 ],
#        [  0.6808118 ,   0.69594234,  -2.761194  ,  -2.7885146 ,
#          -0.74454194,  -3.3363578 ],
#        [ -3.8169045 ,  -7.4259596 ,   2.1273797 ,  -1.1726587 ,
#          -8.207032  ,  -4.1870413 ],
#        [ -1.9861712 ,  -4.1603913 ,  -0.42739105,  -0.45656568,
#         -10.390229  ,  -2.605057  ]], dtype=float32)

# %%
import numpy as np

y_pred = model.predict(val_ds)

         #   test.Peruntukan == "Pasar",
          #   test.Peruntukan == "Kantor",
           #  test.Peruntukan == "Ruko",
            # test.Peruntukan == "Taman",
             #test.Peruntukan == "Perumahan",
             #test.Peruntukan == "Sawah",
            
         #   value = [5,4,3,2,1,0]
y_pred
# Out:
# array([[ -6.170356  ,  -6.6026406 ,  -4.0836926 ,   2.5129862 ,
#          -3.4265015 ,   1.5201592 ],
#        [ -5.040804  ,  -5.6711435 ,  -0.7012763 ,   1.9127867 ,
#          -5.1664186 ,  -0.87973034],
#        [ -6.245297  ,  -6.809353  ,  -4.1011806 ,   2.5699062 ,
#          -3.358107  ,   1.3658398 ],
#        [ -5.964391  ,  -6.1752987 ,  -4.0602484 ,   2.3211222 ,
#          -3.5524652 ,   1.8369466 ],
#        [ -6.0154324 ,  -6.2779884 ,  -4.0661225 ,   2.3721662 ,
#          -3.5218713 ,   1.7621956 ],
#        [ -6.270488  ,  -6.8788357 ,  -4.1070585 ,   2.5890388 ,
#          -3.3351173 ,   1.3139676 ],
#        [ -6.1843367 ,  -6.641203  ,  -4.086955  ,   2.5236053 ,
#          -3.4137423 ,   1.4913703 ],
#        [ -3.734487  ,  -4.9783363 ,  -1.0361936 ,   2.282444  ,
#          -2.9204946 ,  -1.5747201 ],
#        [ -3.7557874 ,  -5.0598125 ,  -1.046736  ,   2.266955  ,
#          -2.9073663 ,  -1.6236441 ],
#        [ -8.207413  ,  -5.289465  , -19.333277  ,  -0.15548074,
#         -18.820496  ,   5.740004  ],
#        [ -3.1032982 ,  -3.590541  ,  -1.0823898 ,   2.235108  ,
#          -3.2773287 ,  -0.81796515],
#        [ -3.221111  ,  -3.8198833 ,  -1.0463555 ,   2.251553  ,
#          -3.182736  ,  -0.90971494],
#        [ -6.133031  ,  -6.5085497 ,  -4.0768857 ,   2.4839225 ,
#          -3.4562147 ,   1.590996  ],
#        [ -5.497711  ,  -5.2687597 ,  -3.997436  ,   1.8365762 ,
#          -3.8101158 ,   2.4473774 ],
#        [ -6.684995  ,  -4.7900267 , -13.027074  ,   1.0484134 ,
#         -11.588655  ,   4.776993  ],
#        [ -6.1653175 ,  -6.5887437 ,  -4.082517  ,   2.50916   ,
#          -3.4310994 ,   1.5305339 ],
#        [ -6.084116  ,  -6.416172  ,  -4.074027  ,   2.4408536 ,
#          -3.4807029 ,   1.6616071 ],
#        [ -4.844545  ,  -4.3987684 ,  -5.4880657 ,   1.5086125 ,
#          -4.5566883 ,   2.9960878 ],
#        [ -1.8127067 ,  -3.5173695 ,  -5.117794  ,  -2.8856425 ,
#           3.7268913 ,  -1.7398533 ],
#        [ -1.8065253 ,  -3.4596334 ,  -5.093666  ,  -2.883654  ,
#           3.7073295 ,  -1.725398  ],
#        [ -2.4802222 ,  -0.23914269,  -5.1130624 ,  -3.3440938 ,
#           1.2749428 ,  -2.9277773 ],
#        [ -1.8009322 ,  -3.4073956 ,  -5.071836  ,  -2.8818555 ,
#           3.6896305 ,  -1.7123191 ],
#        [  4.205394  ,  -2.3631883 ,  -2.9542215 ,  -8.279393  ,
#          -5.150969  ,  -6.338446  ],
#        [  4.377611  ,   0.6289182 ,  -4.648347  ,  -7.8268967 ,
#          -7.3412385 ,  -5.826607  ],
#        [  4.12768   ,  -2.7138603 ,  -2.9770088 ,  -8.291442  ,
#          -4.9224353 ,  -6.4424095 ],
#        [  4.379246  ,  -1.2347128 ,  -2.9835477 ,  -8.251963  ,
#          -5.8195415 ,  -5.9402227 ],
#        [  4.337919  ,  -0.35161707,  -3.4873817 ,  -8.018976  ,
#          -6.5055375 ,  -5.758626  ],
#        [  4.361499  ,  -1.3661151 ,  -2.975227  ,  -8.2526455 ,
#          -5.7448545 ,  -5.9886556 ],
#        [  4.3909473 ,  -1.0805409 ,  -3.013743  ,  -8.230163  ,
#          -5.9257164 ,  -5.907989  ],
#        [ -1.793741  ,   1.040507  , -18.511053  ,  -6.709225  ,
#         -17.752306  ,  -1.2439113 ],
#        [ -0.57282454,   1.6056272 , -12.635883  ,  -5.3017735 ,
#         -11.029435  ,  -2.0761087 ],
#        [  0.6808118 ,   0.69594234,  -2.761194  ,  -2.7885146 ,
#          -0.74454194,  -3.3363578 ],
#        [ -3.8169045 ,  -7.4259596 ,   2.1273797 ,  -1.1726587 ,
#          -8.207032  ,  -4.1870413 ],
#        [ -1.9861712 ,  -4.1603913 ,  -0.42739105,  -0.45656568,
#         -10.390229  ,  -2.605057  ]], dtype=float32)

# %%
val_ds
# Out:
# <BatchDataset element_spec=({'Pusat_kota': TensorSpec(shape=(None,), dtype=tf.int64, name=None), 'Visibilitas': TensorSpec(shape=(None,), dtype=tf.int64, name=None), 'Bangunan': TensorSpec(shape=(None,), dtype=tf.int64, name=None), 'Luas': TensorSpec(shape=(None,), dtype=tf.int64, name=None)}, TensorSpec(shape=(None,), dtype=tf.int64, name=None))>

# %%
# Ubah output prediksi menjadi label kelas
label_kelas = ['Sawah', 'Perumahan', 'Taman', 'Ruko', 'Kantor', 'Pasar']
y_pred_label = [label_kelas[np.argmax(prediksi)] for prediksi in y_pred]

# Tampilkan hasil prediksi
print(y_pred_label)
# Out:
# ['Ruko', 'Ruko', 'Ruko', 'Ruko', 'Ruko', 'Ruko', 'Ruko', 'Ruko', 'Ruko', 'Pasar', 'Ruko', 'Ruko', 'Ruko', 'Pasar', 'Pasar', 'Ruko', 'Ruko', 'Pasar', 'Kantor', 'Kantor', 'Kantor', 'Kantor', 'Sawah', 'Sawah', 'Sawah', 'Sawah', 'Sawah', 'Sawah', 'Sawah', 'Perumahan', 'Perumahan', 'Perumahan', 'Taman', 'Taman']

# %%
for x in y_pred_label:
    print(x)
# Out:
# Ruko
# Ruko
# Ruko
# Ruko
# Ruko
# Ruko
# Ruko
# Ruko
# Ruko
# Pasar
# Ruko
# Ruko
# Ruko
# Pasar
# Pasar
# Ruko
# Ruko
# Pasar
# Kantor
# Kantor
# Kantor
# Kantor
# Sawah
# Sawah
# Sawah
# Sawah
# Sawah
# Sawah
# Sawah
# Perumahan
# Perumahan
# Perumahan
# Taman
# Taman
