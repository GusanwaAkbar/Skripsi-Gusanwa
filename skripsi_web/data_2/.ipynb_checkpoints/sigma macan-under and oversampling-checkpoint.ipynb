# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
import matplotlib.pyplot as plt

import keras
import sklearn
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.callbacks import ModelCheckpoint

import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

from sklearn.metrics import confusion_matrix
# Out:
# 2023-05-30 04:03:26.494999: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-05-30 04:03:26.495044: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# # Import the data

# %%
import pandas as pd
from sklearn.utils import shuffle

# Read the CSV file into a pandas DataFrame
data = pd.read_csv("rumus + data skripsi angka polos jarak dan visibilitas 2.csv")

# %%
def get_data_with_ratio(ratio):
    # Shuffle the data
    shuffled_data = data

    # Get unique classes from the "Peruntukan" column
    classes = shuffled_data['Peruntukan'].unique()

    # Initialize empty dataframes for train and test data
    train_data = pd.DataFrame()
    test_data = pd.DataFrame()

    # Iterate over each class
    for cls in classes:
        cls_data = shuffled_data[shuffled_data['Peruntukan'] == cls]

        # Split the class data into train and test
        cls_train, cls_test = train_test_split(cls_data, test_size=ratio, random_state = 102,shuffle = True)

        # Append the train and test data to the respective dataframes
        train_data = train_data.append(cls_train)
        test_data = test_data.append(cls_test)
        
    training = train_data
    test = test_data

    training = training[["Peruntukan","Jarak_pusat_kota2","Visibilitas","Bangunan","Luas"]]
    test = test[["Peruntukan","Jarak_pusat_kota2","Visibilitas","Bangunan","Luas"]]

    print(training)
    print(test)
    training = pd.read_csv('training_underover2.csv')
    training.to_csv('training_underover.csv', index=False)
    test.to_csv('testing_underover.csv', index=False)
    
    return training, test

# %% [markdown]
# # Data visualisasi

# %% [markdown]
# # Change categorical to number

# %%
def change_categorical_to_number(data):
    
    data = data
    
 
    ####
    ####

    condition = [  data.Visibilitas == "Strategis",
                 data.Visibilitas == "Sedang",
                  data.Visibilitas == "Kurang",
    ]

    value = [3,2,1]

    data.Visibilitas = np.select(condition,value)
    #####
    #####

    condition = [  data.Bangunan == "Bagus",
                 data.Bangunan == "Sedang",

    ]

    value = [2,1]

    data.Bangunan = np.select(condition,value,0)


    condition = [ 
                data.Peruntukan == "Pasar",
                 data.Peruntukan == "Kantor",
                 data.Peruntukan == "Ruko",
                 data.Peruntukan == "Taman",
                 data.Peruntukan == "Perumahan",
                 data.Peruntukan == "Sawah",

    ]

    value = [5,4,3,2,1,0]

    data.Peruntukan = np.select(condition,value,0)
    
    return data

# %% [markdown]
# # Dataframe to Dataset

# %%
def df_to_dataset(dataframe, shuffle=False, batch_size=1):
  dataframe = dataframe.copy()
  labels = dataframe.pop('Peruntukan')
  ds = tf.data.Dataset.from_tensor_slices((dict(dataframe), labels))
  if shuffle:
    ds = ds.shuffle(buffer_size=len(dataframe))
  ds = ds.batch(batch_size)
  return ds

# %% [markdown]
# # Feature Normalizer

# %%
def get_normalization_layer(name, dataset):
  # Create a Normalization layer for the feature.
  normalizer = layers.Normalization(axis=None)

  # Prepare a Dataset that only yields the feature.
  feature_ds = dataset.map(lambda x, y: x[name])

  # Learn the statistics of the data.
  normalizer.adapt(feature_ds)

  return normalizer

# %%
def encoded_features(train_ds):
    all_inputs = []
    encoded_features = []

    # Numerical features.
    for header in ["Jarak_pusat_kota2","Visibilitas","Bangunan","Luas"]:
      numeric_col = tf.keras.Input(shape=(1,), name=header)
      normalization_layer = get_normalization_layer(header, train_ds)
      encoded_numeric_col = normalization_layer(numeric_col)
      all_inputs.append(numeric_col)
      encoded_features.append(encoded_numeric_col)
    return encoded_features, all_inputs

# %%
checkpoint_callback = ModelCheckpoint("best_model.h5", monitor='val_accuracy', save_best_only=True, mode='max')

# %% [markdown]
# # Model build

# %%
def model(encoded_features,all_inputs):
    
    all_features = tf.keras.layers.concatenate(encoded_features)
    x = tf.keras.layers.Dense(32, activation="relu")(all_features)
    x = tf.keras.layers.Dropout(0.5)(x)
    output = tf.keras.layers.Dense(6)(x)

    model = tf.keras.Model(all_inputs, output)

    model.compile(optimizer='adam',
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                  metrics="accuracy",
                 )
    
    return model

# %% [markdown]
# # History build

# %%
def history(model,callbacks,train_ds,val_ds):
    

    history = model.fit(train_ds, epochs=150, validation_data=val_ds, callbacks=callbacks)

    # Get the training and validation metrics from the history
    train_accuracy = history.history['accuracy']
    val_accuracy = history.history['val_accuracy']
    train_loss = history.history['loss']
    val_loss = history.history['val_loss']

    # Plot accuracy
    plt.plot(train_accuracy, label='Training Accuracy')
    plt.plot(val_accuracy, label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

    # Plot loss
    plt.plot(train_loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()
    
    max_test_accuracy_index = history.history['val_accuracy'].index(max(history.history['val_accuracy']))

    # Get the corresponding training accuracy
    training_accuracy = history.history['accuracy'][max_test_accuracy_index]

    print('Best validation accuracy:', max(history.history['val_accuracy']))
    print('Training accuracy at the best test accuracy:', training_accuracy)
    
    return history

# %% [markdown]
# # Evaluation the Model

# %%
def run_model(ratio,callbacks):
    
    #split data
    training, test_2 = get_data_with_ratio(ratio)
    
    #change data to number
    training = change_categorical_to_number(training)
    test = change_categorical_to_number(test_2)
    
    #df to ds
    
    train_ds = df_to_dataset(training)
    val_ds = df_to_dataset(test)
    
    #encoded features
    
    encoded,inputs = encoded_features(train_ds)

    
    #set the model
    model_engine = model(encoded,inputs)
    
    #run and evaluate the model
    model_engine2 = history(model_engine,callbacks,train_ds,val_ds)
    
    #evaluate confusion matrix
    confussion_matrix(model_engine2,val_ds,test_2)

# %%
def confussion_matrix(best_model, val_ds, test_data):
    from sklearn.metrics import confusion_matrix   
    model = best_model
    
    y_pred = model.model.predict(val_ds)

    # Ubah output prediksi menjadi label kelas
    label_kelas = [0, 1, 2, 3, 4, 5]
    y_pred_label = [label_kelas[np.argmax(prediksi)] for prediksi in y_pred]

    # Test labels
    test_labels = test_data.Peruntukan

    # Calculate the confusion matrix
    cm = confusion_matrix(test_labels, y_pred_label)
    
    val_accuracy = model.history['val_accuracy']
    train_accuracy = model.history['accuracy']

    # Find the index where validation accuracy is highest
    max_val_accuracy_index = np.argmax(val_accuracy)

    # Find the index of the closest training accuracy to the maximum validation accuracy
    closest_train_accuracy_index = np.argmin([abs(i - max_val_accuracy_index) for i in range(len(train_accuracy))])

    print('Best validation accuracy:', val_accuracy[max_val_accuracy_index])
    print('Closest training accuracy to the maximum validation accuracy:', train_accuracy[closest_train_accuracy_index])




    print('Confusion matrix:')
    print(cm)
    
    confusion_matrix = cm
    
    true_positives = np.diagonal(confusion_matrix)

    # Step 3: Calculate the accuracy percentage for each class
    class_data_totals = np.sum(confusion_matrix, axis=0)
    class_accuracies = true_positives / class_data_totals * 100

    # Step 4: Calculate the overall accuracy percentage
    total_instances = np.sum(confusion_matrix)
    overall_accuracy = np.sum(true_positives) / total_instances * 100

    
 
    
    
    
    true_positives = np.diagonal(confusion_matrix)
    false_positives = np.sum(confusion_matrix, axis=0) - true_positives
    false_negatives = np.sum(confusion_matrix, axis=1) - true_positives

    # Step 3: Calculate precision, recall, and F1 score for each label
    accuracy = true_positives / np.sum(confusion_matrix, axis=1)
    precision = true_positives / (true_positives + false_positives)
    recall = true_positives / (true_positives + false_negatives)
    f1_score = 2 * (precision * recall) / (precision + recall)

    # Step 4: Calculate the total accuracy
    total_accuracy = np.sum(true_positives) / np.sum(confusion_matrix) * 100
    total_precision = np.mean(precision)
    total_recall = np.mean(recall)
    total_f1 = np.mean(f1_score)

    # Print the results
    print("Total Accuracy:", total_accuracy)
    print("Total Precision:", total_precision)
    print("Total Recall:", total_recall)
    
    print("TP for each label", true_positives)
    print("Total data for each label",  np.sum(confusion_matrix, axis=1))
    print("FP for each label", np.sum(confusion_matrix, axis=0) - true_positives)
    print("FN for each label", np.sum(confusion_matrix, axis=1) - true_positives)
    # Print the results
    print("Accuracy for each label:", class_accuracies)
    print("Precision for each label:", precision)
    print("Recall for each label:", recall)

# %% [markdown]
# # Model Evaluation

# %%
callback_1 = ModelCheckpoint("50.h5", monitor='val_accuracy', save_best_only=True, mode='max')
ratio_1 = 0.5

callback_2= ModelCheckpoint("40.h5", monitor='val_accuracy', save_best_only=True, mode='max')
ratio_2 = 0.4

callback_3= ModelCheckpoint("30.h5", monitor='val_accuracy', save_best_only=True, mode='max')
ratio_3 = 0.3

callback_4= ModelCheckpoint("20.h5", monitor='val_accuracy', save_best_only=True, mode='max')
ratio_4 = 0.2

callback_5= ModelCheckpoint("10.h5", monitor='val_accuracy', save_best_only=True, mode='max')
ratio_5 = 0.1

# %%
run_model(ratio_1, callback_1)
# Out:
# /tmp/ipykernel_544937/102179616.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(cls_train)
# /tmp/ipykernel_544937/102179616.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data = test_data.append(cls_test)
# /tmp/ipykernel_544937/102179616.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(cls_train)
# /tmp/ipykernel_544937/102179616.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data = test_data.append(cls_test)
# /tmp/ipykernel_544937/102179616.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(cls_train)
# /tmp/ipykernel_544937/102179616.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data = test_data.append(cls_test)
# /tmp/ipykernel_544937/102179616.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(cls_train)
# /tmp/ipykernel_544937/102179616.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data = test_data.append(cls_test)
# /tmp/ipykernel_544937/102179616.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(cls_train)
# /tmp/ipykernel_544937/102179616.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data = test_data.append(cls_test)
# /tmp/ipykernel_544937/102179616.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(cls_train)
# /tmp/ipykernel_544937/102179616.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data = test_data.append(cls_test)
# 2023-05-30 04:03:34.410533: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-05-30 04:03:34.410583: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-05-30 04:03:34.410611: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (gusanwa): /proc/driver/nvidia/version does not exist
# 2023-05-30 04:03:34.410912: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
#     Peruntukan  Jarak_pusat_kota2 Visibilitas Bangunan   Luas
# 57       Pasar        1031.829535   Strategis   Sedang   2252
# 43       Pasar        1676.146577   Strategis   Sedang   3840
# 29       Pasar        1730.459693   Strategis   Sedang   5784
# 32       Pasar        2406.214384   Strategis   Sedang   5200
# 41       Pasar        1839.107811   Strategis   Sedang   3987
# 11       Pasar         765.887686   Strategis    Bagus  15710
# 69       Pasar        3310.271455   Strategis   Sedang   1490
# 64       Pasar        1703.886238   Strategis   Sedang   1735
# 0        Pasar        2592.305034   Strategis   Sedang  87580
# 5    Perumahan        2535.506573      Sedang   Sedang  27024
# 10   Perumahan        4519.160513      Kurang   Sedang  16590
# 1    Perumahan        2289.806804      Sedang   Sedang  87580
# 31       Sawah        5402.735138      Kurang   Kosong   5700
# 22       Sawah        2766.267155      Kurang   Kosong   6635
# 23       Sawah        4216.298352      Kurang   Kosong   6390
# 25       Sawah        2769.702392      Kurang   Kosong   6065
# 7        Sawah        1998.062583      Kurang   Kosong  18110
# 40       Sawah        2343.606060      Kurang   Kosong   4000
# 56       Sawah        2119.585885      Kurang   Kosong   2370
# 50       Sawah        2614.434517      Kurang   Kosong   3176
# 36       Sawah        5661.330381      Kurang   Kosong   4905
# 52       Sawah        3679.067767      Kurang   Kosong   2786
# 85      Kantor        1772.659281   Strategis    Bagus    410
# 73      Kantor         503.327080   Strategis    Bagus   1192
# 96      Kantor         462.241288   Strategis    Bagus    175
# 68      Kantor         514.990494   Strategis    Bagus   1492
# 34      Kantor         181.231532   Strategis    Bagus   5070
# 97      Kantor         639.829998   Strategis    Bagus    150
# 72      Kantor         506.185702   Strategis    Bagus   1217
# 89        Ruko         414.732403   Strategis   Sedang    311
# 60        Ruko         545.454479      Sedang   Sedang   2000
# 88        Ruko        1444.166542      Sedang   Sedang    335
# 45        Ruko        1748.604165      Sedang   Sedang   3720
# 95        Ruko        1316.067805      Sedang   Sedang    200
# 99        Ruko        1169.528081   Strategis   Sedang     90
# 33        Ruko        2255.307555      Sedang   Sedang   5150
# 55        Ruko        2305.804817      Sedang   Sedang   2379
# 83        Ruko        2030.342887      Sedang   Sedang    500
# 93        Ruko        3212.361013      Sedang   Sedang    229
# 87        Ruko        1471.417607   Strategis   Sedang    366
# 84        Ruko         874.840952   Strategis   Sedang    421
# 79        Ruko        1059.810560   Strategis   Sedang    754
# 101       Ruko       17703.461987      Sedang   Sedang     70
# 86        Ruko        1690.218450   Strategis   Sedang    380
# 102       Ruko        3119.342342      Sedang   Sedang   1200
# 38        Ruko        1837.817058   Strategis   Sedang   4135
# Epoch 1/150
# 47/47 [==============================] - 1s 8ms/step - loss: 2.0209 - accuracy: 0.2340 - val_loss: 1.8503 - val_accuracy: 0.2963
# Epoch 2/150
# 47/47 [==============================] - 0s 5ms/step - loss: 1.8258 - accuracy: 0.3191 - val_loss: 1.7691 - val_accuracy: 0.5000
# Epoch 3/150
# 47/47 [==============================] - 0s 4ms/step - loss: 1.7244 - accuracy: 0.4468 - val_loss: 1.6831 - val_accuracy: 0.5000
# Epoch 4/150
# 47/47 [==============================] - 0s 5ms/step - loss: 1.5815 - accuracy: 0.4255 - val_loss: 1.6024 - val_accuracy: 0.5185
# Epoch 5/150
# 47/47 [==============================] - 0s 4ms/step - loss: 1.5932 - accuracy: 0.3617 - val_loss: 1.5411 - val_accuracy: 0.5185
# Epoch 6/150
# 47/47 [==============================] - 0s 4ms/step - loss: 1.4935 - accuracy: 0.4468 - val_loss: 1.4762 - val_accuracy: 0.5185
# Epoch 7/150
# 47/47 [==============================] - 0s 4ms/step - loss: 1.5131 - accuracy: 0.4043 - val_loss: 1.4152 - val_accuracy: 0.5185
# Epoch 8/150
# 47/47 [==============================] - 0s 5ms/step - loss: 1.5133 - accuracy: 0.4894 - val_loss: 1.3547 - val_accuracy: 0.6111
# Epoch 9/150
# 47/47 [==============================] - 0s 5ms/step - loss: 1.3073 - accuracy: 0.5106 - val_loss: 1.2969 - val_accuracy: 0.6667
# Epoch 10/150
# 47/47 [==============================] - 0s 5ms/step - loss: 1.3305 - accuracy: 0.6170 - val_loss: 1.2459 - val_accuracy: 0.6852
# Epoch 11/150
# 47/47 [==============================] - 0s 4ms/step - loss: 1.2568 - accuracy: 0.5532 - val_loss: 1.2051 - val_accuracy: 0.6852
# Epoch 12/150
# 47/47 [==============================] - 0s 4ms/step - loss: 1.2598 - accuracy: 0.5957 - val_loss: 1.1632 - val_accuracy: 0.6852
# Epoch 13/150
# 47/47 [==============================] - 0s 4ms/step - loss: 1.1113 - accuracy: 0.6596 - val_loss: 1.1232 - val_accuracy: 0.6852
# Epoch 14/150
# 47/47 [==============================] - 0s 4ms/step - loss: 1.1632 - accuracy: 0.5745 - val_loss: 1.0908 - val_accuracy: 0.6852
# Epoch 15/150
# 47/47 [==============================] - 0s 5ms/step - loss: 1.1305 - accuracy: 0.6383 - val_loss: 1.0611 - val_accuracy: 0.7037
# Epoch 16/150
# 47/47 [==============================] - 0s 4ms/step - loss: 1.0925 - accuracy: 0.6809 - val_loss: 1.0376 - val_accuracy: 0.7037
# Epoch 17/150
# 47/47 [==============================] - 0s 4ms/step - loss: 1.0606 - accuracy: 0.6596 - val_loss: 1.0119 - val_accuracy: 0.7037
# Epoch 18/150
# 47/47 [==============================] - 0s 3ms/step - loss: 0.9987 - accuracy: 0.6809 - val_loss: 0.9892 - val_accuracy: 0.7037
# Epoch 19/150
# 47/47 [==============================] - 0s 4ms/step - loss: 1.0629 - accuracy: 0.6596 - val_loss: 0.9696 - val_accuracy: 0.7407
# Epoch 20/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.9428 - accuracy: 0.6809 - val_loss: 0.9508 - val_accuracy: 0.7407
# Epoch 21/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.9059 - accuracy: 0.6809 - val_loss: 0.9333 - val_accuracy: 0.7407
# Epoch 22/150
# 47/47 [==============================] - 0s 4ms/step - loss: 1.0219 - accuracy: 0.5745 - val_loss: 0.9141 - val_accuracy: 0.7407
# Epoch 23/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.9035 - accuracy: 0.7447 - val_loss: 0.9009 - val_accuracy: 0.7593
# Epoch 24/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.8548 - accuracy: 0.7021 - val_loss: 0.8819 - val_accuracy: 0.7963
# Epoch 25/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.8580 - accuracy: 0.7447 - val_loss: 0.8649 - val_accuracy: 0.7778
# Epoch 26/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.8571 - accuracy: 0.7660 - val_loss: 0.8539 - val_accuracy: 0.7963
# Epoch 27/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.8046 - accuracy: 0.7872 - val_loss: 0.8394 - val_accuracy: 0.7963
# Epoch 28/150
# 47/47 [==============================] - 0s 5ms/step - loss: 0.8128 - accuracy: 0.7447 - val_loss: 0.8266 - val_accuracy: 0.8148
# Epoch 29/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.8485 - accuracy: 0.7021 - val_loss: 0.8183 - val_accuracy: 0.7963
# Epoch 30/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.9455 - accuracy: 0.6809 - val_loss: 0.8078 - val_accuracy: 0.7963
# Epoch 31/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.7846 - accuracy: 0.6809 - val_loss: 0.7983 - val_accuracy: 0.7963
# Epoch 32/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.7204 - accuracy: 0.7447 - val_loss: 0.7848 - val_accuracy: 0.8148
# Epoch 33/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.6939 - accuracy: 0.7660 - val_loss: 0.7741 - val_accuracy: 0.8333
# Epoch 34/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.8488 - accuracy: 0.7660 - val_loss: 0.7676 - val_accuracy: 0.8148
# Epoch 35/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.7413 - accuracy: 0.7234 - val_loss: 0.7538 - val_accuracy: 0.8148
# Epoch 36/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.6812 - accuracy: 0.8298 - val_loss: 0.7486 - val_accuracy: 0.8148
# Epoch 37/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.7293 - accuracy: 0.6809 - val_loss: 0.7389 - val_accuracy: 0.8148
# Epoch 38/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.6176 - accuracy: 0.7660 - val_loss: 0.7332 - val_accuracy: 0.8148
# Epoch 39/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.7284 - accuracy: 0.7660 - val_loss: 0.7231 - val_accuracy: 0.8148
# Epoch 40/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.6695 - accuracy: 0.7660 - val_loss: 0.7128 - val_accuracy: 0.8333
# Epoch 41/150
# 47/47 [==============================] - 0s 5ms/step - loss: 0.8002 - accuracy: 0.7660 - val_loss: 0.7071 - val_accuracy: 0.8704
# Epoch 42/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.7036 - accuracy: 0.7872 - val_loss: 0.7010 - val_accuracy: 0.8704
# Epoch 43/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.6036 - accuracy: 0.8298 - val_loss: 0.6930 - val_accuracy: 0.8519
# Epoch 44/150
# 47/47 [==============================] - 0s 5ms/step - loss: 0.7040 - accuracy: 0.7660 - val_loss: 0.6882 - val_accuracy: 0.8704
# Epoch 45/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.5222 - accuracy: 0.8511 - val_loss: 0.6837 - val_accuracy: 0.8704
# Epoch 46/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.6357 - accuracy: 0.7660 - val_loss: 0.6763 - val_accuracy: 0.8704
# Epoch 47/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.6666 - accuracy: 0.7872 - val_loss: 0.6661 - val_accuracy: 0.8704
# Epoch 48/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.6319 - accuracy: 0.7872 - val_loss: 0.6642 - val_accuracy: 0.8704
# Epoch 49/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.5256 - accuracy: 0.8511 - val_loss: 0.6619 - val_accuracy: 0.8333
# Epoch 50/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.4560 - accuracy: 0.8723 - val_loss: 0.6563 - val_accuracy: 0.8333
# Epoch 51/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.5801 - accuracy: 0.8298 - val_loss: 0.6490 - val_accuracy: 0.8333
# Epoch 52/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.5231 - accuracy: 0.8085 - val_loss: 0.6446 - val_accuracy: 0.8704
# Epoch 53/150
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4824 - accuracy: 0.8936 - val_loss: 0.6368 - val_accuracy: 0.8519
# Epoch 54/150
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4713 - accuracy: 0.9149 - val_loss: 0.6353 - val_accuracy: 0.8704
# Epoch 55/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.5773 - accuracy: 0.7872 - val_loss: 0.6333 - val_accuracy: 0.8704
# Epoch 56/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.5545 - accuracy: 0.8085 - val_loss: 0.6303 - val_accuracy: 0.8333
# Epoch 57/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.6929 - accuracy: 0.7021 - val_loss: 0.6214 - val_accuracy: 0.8519
# Epoch 58/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.5991 - accuracy: 0.7234 - val_loss: 0.6181 - val_accuracy: 0.8704
# Epoch 59/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.4803 - accuracy: 0.8298 - val_loss: 0.6130 - val_accuracy: 0.8704
# Epoch 60/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.6341 - accuracy: 0.7660 - val_loss: 0.6089 - val_accuracy: 0.8704
# Epoch 61/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.4875 - accuracy: 0.8511 - val_loss: 0.6080 - val_accuracy: 0.8704
# Epoch 62/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.5243 - accuracy: 0.8085 - val_loss: 0.6026 - val_accuracy: 0.8889
# Epoch 63/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.5407 - accuracy: 0.8511 - val_loss: 0.6015 - val_accuracy: 0.8889
# Epoch 64/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.5455 - accuracy: 0.8085 - val_loss: 0.6055 - val_accuracy: 0.8889
# Epoch 65/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.5238 - accuracy: 0.7447 - val_loss: 0.6002 - val_accuracy: 0.8704
# Epoch 66/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.5887 - accuracy: 0.7660 - val_loss: 0.6000 - val_accuracy: 0.8704
# Epoch 67/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.4684 - accuracy: 0.8085 - val_loss: 0.5974 - val_accuracy: 0.8704
# Epoch 68/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.5121 - accuracy: 0.7872 - val_loss: 0.5976 - val_accuracy: 0.8704
# Epoch 69/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.5292 - accuracy: 0.7234 - val_loss: 0.5967 - val_accuracy: 0.8704
# Epoch 70/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.5591 - accuracy: 0.8298 - val_loss: 0.5948 - val_accuracy: 0.8889
# Epoch 71/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.5331 - accuracy: 0.7872 - val_loss: 0.5939 - val_accuracy: 0.8704
# Epoch 72/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.4968 - accuracy: 0.7660 - val_loss: 0.5945 - val_accuracy: 0.8519
# Epoch 73/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.4931 - accuracy: 0.8085 - val_loss: 0.5918 - val_accuracy: 0.8519
# Epoch 74/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.4823 - accuracy: 0.8298 - val_loss: 0.5914 - val_accuracy: 0.8519
# Epoch 75/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.4736 - accuracy: 0.8511 - val_loss: 0.5925 - val_accuracy: 0.8889
# Epoch 76/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.5130 - accuracy: 0.7872 - val_loss: 0.5875 - val_accuracy: 0.8704
# Epoch 77/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.5871 - accuracy: 0.7447 - val_loss: 0.5835 - val_accuracy: 0.8889
# Epoch 78/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.
150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3946 - accuracy: 0.8511 - val_loss: 0.5906 - val_accuracy: 0.8519
# Epoch 111/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3561 - accuracy: 0.8723 - val_loss: 0.5899 - val_accuracy: 0.8704
# Epoch 112/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.4167 - accuracy: 0.8298 - val_loss: 0.5908 - val_accuracy: 0.8704
# Epoch 113/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3658 - accuracy: 0.8936 - val_loss: 0.5889 - val_accuracy: 0.8704
# Epoch 114/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3911 - accuracy: 0.7872 - val_loss: 0.5899 - val_accuracy: 0.8704
# Epoch 115/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.4108 - accuracy: 0.8723 - val_loss: 0.5918 - val_accuracy: 0.8889
# Epoch 116/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3975 - accuracy: 0.8298 - val_loss: 0.5929 - val_accuracy: 0.8704
# Epoch 117/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.4145 - accuracy: 0.8085 - val_loss: 0.5911 - val_accuracy: 0.8704
# Epoch 118/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.4207 - accuracy: 0.8085 - val_loss: 0.5879 - val_accuracy: 0.8704
# Epoch 119/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3899 - accuracy: 0.8085 - val_loss: 0.5856 - val_accuracy: 0.8704
# Epoch 120/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.2913 - accuracy: 0.8936 - val_loss: 0.5841 - val_accuracy: 0.8519
# Epoch 121/150
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3407 - accuracy: 0.8723 - val_loss: 0.5880 - val_accuracy: 0.8519
# Epoch 122/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.4623 - accuracy: 0.8511 - val_loss: 0.5865 - val_accuracy: 0.8704
# Epoch 123/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3565 - accuracy: 0.8511 - val_loss: 0.5838 - val_accuracy: 0.8704
# Epoch 124/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3778 - accuracy: 0.8723 - val_loss: 0.5865 - val_accuracy: 0.8704
# Epoch 125/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3046 - accuracy: 0.8936 - val_loss: 0.5882 - val_accuracy: 0.8704
# Epoch 126/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3753 - accuracy: 0.8298 - val_loss: 0.5912 - val_accuracy: 0.8519
# Epoch 127/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3907 - accuracy: 0.8298 - val_loss: 0.5917 - val_accuracy: 0.8704
# Epoch 128/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3824 - accuracy: 0.8298 - val_loss: 0.5920 - val_accuracy: 0.8704
# Epoch 129/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.4241 - accuracy: 0.8085 - val_loss: 0.5927 - val_accuracy: 0.8704
# Epoch 130/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3929 - accuracy: 0.8085 - val_loss: 0.5894 - val_accuracy: 0.8704
# Epoch 131/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3422 - accuracy: 0.8723 - val_loss: 0.5932 - val_accuracy: 0.8704
# Epoch 132/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3508 - accuracy: 0.8723 - val_loss: 0.5946 - val_accuracy: 0.8704
# Epoch 133/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.4073 - accuracy: 0.8511 - val_loss: 0.5959 - val_accuracy: 0.8519
# Epoch 134/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3913 - accuracy: 0.8936 - val_loss: 0.5960 - val_accuracy: 0.8519
# Epoch 135/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.4241 - accuracy: 0.7660 - val_loss: 0.5977 - val_accuracy: 0.8519
# Epoch 136/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3466 - accuracy: 0.8085 - val_loss: 0.5989 - val_accuracy: 0.8519
# Epoch 137/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3516 - accuracy: 0.7872 - val_loss: 0.6000 - val_accuracy: 0.8704
# Epoch 138/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.2846 - accuracy: 0.8936 - val_loss: 0.5985 - val_accuracy: 0.8704
# Epoch 139/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3385 - accuracy: 0.9149 - val_loss: 0.5971 - val_accuracy: 0.8704
# Epoch 140/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3308 - accuracy: 0.8723 - val_loss: 0.5973 - val_accuracy: 0.8704
# Epoch 141/150
# 47/47 [==============================] - 0s 5ms/step - loss: 0.3450 - accuracy: 0.8298 - val_loss: 0.5956 - val_accuracy: 0.8519
# Epoch 142/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.4332 - accuracy: 0.7660 - val_loss: 0.5862 - val_accuracy: 0.8704
# Epoch 143/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3606 - accuracy: 0.8085 - val_loss: 0.5857 - val_accuracy: 0.8704
# Epoch 144/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.4197 - accuracy: 0.8085 - val_loss: 0.5876 - val_accuracy: 0.8704
# Epoch 145/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.4457 - accuracy: 0.8085 - val_loss: 0.5891 - val_accuracy: 0.8704
# Epoch 146/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3205 - accuracy: 0.8511 - val_loss: 0.5901 - val_accuracy: 0.8704
# Epoch 147/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.2835 - accuracy: 0.8511 - val_loss: 0.5913 - val_accuracy: 0.8704
# Epoch 148/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3463 - accuracy: 0.8298 - val_loss: 0.5948 - val_accuracy: 0.8704
# Epoch 149/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3362 - accuracy: 0.8085 - val_loss: 0.5940 - val_accuracy: 0.8704
# Epoch 150/150
# 47/47 [==============================] - 0s 4ms/step - loss: 0.3683 - accuracy: 0.8511 - val_loss: 0.5971 - val_accuracy: 0.8704
# Best validation accuracy: 0.8888888955116272
# Training accuracy at the best test accuracy: 0.8085106611251831
# Best validation accuracy: 0.8888888955116272
# Closest training accuracy to the maximum validation accuracy: 0.8085106611251831
# Confusion matrix:
# [[11  0  1  0  0  0]
#  [ 0  2  0  0  0  2]
#  [ 0  0  3  0  0  0]
#  [ 0  0  0 15  0  2]
#  [ 0  0  0  0  8  0]
#  [ 0  0  0  1  1  8]]
# Total Accuracy: 87.03703703703704
# Total Precision: 0.8738425925925927
# Total Recall: 0.8498366013071895
# TP for each label [11  2  3 15  8  8]
# Total data for each label [12  4  3 17  8 10]
# FP for each label [0 0 1 1 1 4]
# FN for each label [1 2 0 2 0 2]
# Accuracy for each label: [100.         100.          75.          93.75        88.88888889
#   66.66666667]
# Precision for each label: [1.         1.         0.75       0.9375     0.88888889 0.66666667]
# Recall for each label: [0.91666667 0.5        1.         0.88235294 1.         0.8       ]

# %%
#run_model(ratio_2, callback_2)

# %%
#run_model(ratio_3, callback_3)

# %%
#run_model(ratio_4, callback_4)

# %%
#run_model(ratio_5, callback_5)

# %% [markdown]
# #

# %% [markdown]
# # Print the method

# %%
#training, test_2 = get_data_with_ratio(0.5)
#training.head()

# %%
test_2.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 test_2.head()
#
# NameError: name 'test_2' is not defined

# %%
#split data

    
    #change data to number
training = change_categorical_to_number(training)
test = change_categorical_to_number(test_2)

training.head()

# %%
test_2.head()

# %%
train_ds = df_to_dataset(training)
val_ds = df_to_dataset(test)
    
    #encoded features
dataset = train_ds  # Your dataset here

# Create an iterator for the dataset
iterator = dataset.make_one_shot_iterator()

# Get the next element from the iterator
next_element = iterator.get_next()

# Create a TensorFlow session
with tf.Session() as sess:
    try:
        while True:
            # Fetch and print the next element from the dataset
            element = sess.run(next_element)
            print(element)
    except tf.errors.OutOfRangeError:
        # This exception will be raised when all elements have been iterated through
        pass

# %%
dataset = train_ds  # Your dataset here

# Create an iterator for the dataset
iterator = dataset.make_one_shot_iterator()

# Get the next element from the iterator
next_element = iterator.get_next()

# Create a TensorFlow session
with tf.Session() as sess:
    try:
        while True:
            # Fetch and print the next element from the dataset
            element = sess.run(next_element)
            print(element)
    except tf.errors.OutOfRangeError:
        # This exception will be raised when all elements have been iterated through
        pass

# %%
encoded,inputs = encoded_features(train_ds)

# %%
>>> y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
>>> y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
>>> confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])

# %%
y_true
