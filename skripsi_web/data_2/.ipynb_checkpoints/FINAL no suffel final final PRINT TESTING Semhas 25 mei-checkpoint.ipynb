# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
import matplotlib.pyplot as plt

import keras
import sklearn
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.callbacks import ModelCheckpoint

import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

from sklearn.metrics import confusion_matrix
# Out:
# 2023-05-25 07:19:42.905975: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-05-25 07:19:42.906011: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# # Import the data

# %%
import pandas as pd
from sklearn.utils import shuffle

# Read the CSV file into a pandas DataFrame
data = pd.read_csv("rumus + data skripsi angka polos jarak dan visibilitas 2.csv")

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

def get_data_with_ratio(ratio):
    # Membaca data dari file CSV menggunakan Pandas
    data = pd.read_csv("rumus + data skripsi angka polos jarak dan visibilitas 2.csv")
    data = data[["Peruntukan","Jarak_pusat_kota2","Visibilitas","Bangunan","Luas"]]

    # Memisahkan data berdasarkan kolom "Peruntukan"
    peruntukan_data = {}
    for label in ['Sawah', 'Perumahan', 'Taman', 'Ruko', 'Kantor', 'Pasar']:
        peruntukan_data[label] = data[data['Peruntukan'] == label]

    # Memeriksa setiap label untuk memastikan ada minimal satu data
    for label in peruntukan_data:
        if peruntukan_data[label].empty:
            print(f"Label {label} tidak memiliki data yang mewakili")
            return None

    # Menginisialisasi data pelatihan dan pengujian
    train_data = pd.DataFrame()
    test_data = pd.DataFrame()

    # Memisahkan data pelatihan dan pengujian berdasarkan rasio
    for label in peruntukan_data:
        label_train, label_test = train_test_split(peruntukan_data[label], test_size=1-ratio, random_state=42, shuffle = False)
        train_data = train_data.append(label_train)
        test_data = test_data.append(label_test)

    # Mengembalikan data pelatihan dan pengujian
    return train_data, test_data

# %% [markdown]
# # Data visualisasi

# %% [markdown]
# # Change categorical to number

# %%
def change_categorical_to_number(data):
    
    data = data
    
 
    ####
    ####

    condition = [  data.Visibilitas == "Strategis",
                 data.Visibilitas == "Sedang",
                  data.Visibilitas == "Kurang",
    ]

    value = [3,2,1]

    data.Visibilitas = np.select(condition,value)
    #####
    #####

    condition = [  data.Bangunan == "Bagus",
                 data.Bangunan == "Sedang",

    ]

    value = [2,1]

    data.Bangunan = np.select(condition,value,0)


    condition = [ 
                data.Peruntukan == "Pasar",
                 data.Peruntukan == "Kantor",
                 data.Peruntukan == "Ruko",
                 data.Peruntukan == "Taman",
                 data.Peruntukan == "Perumahan",
                 data.Peruntukan == "Sawah",

    ]

    value = [5,4,3,2,1,0]

    data.Peruntukan = np.select(condition,value,0)
    
    return data

# %% [markdown]
# # Dataframe to Dataset

# %%
def df_to_dataset(dataframe, shuffle=False, batch_size=4):
  dataframe = dataframe.copy()
  labels = dataframe.pop('Peruntukan')
  ds = tf.data.Dataset.from_tensor_slices((dict(dataframe), labels))
  if shuffle:
    ds = ds.shuffle(buffer_size=len(dataframe))
  ds = ds.batch(batch_size)
  return ds

# %% [markdown]
# # Feature Normalizer

# %%
def get_normalization_layer(name, dataset):
  # Create a Normalization layer for the feature.
  normalizer = layers.Normalization(axis=None)

  # Prepare a Dataset that only yields the feature.
  feature_ds = dataset.map(lambda x, y: x[name])

  # Learn the statistics of the data.
  normalizer.adapt(feature_ds)

  return normalizer

# %%
def encoded_features(train_ds):
    all_inputs = []
    encoded_features = []

    # Numerical features.
    for header in ["Jarak_pusat_kota2","Visibilitas","Bangunan","Luas"]:
      numeric_col = tf.keras.Input(shape=(1,), name=header)
      normalization_layer = get_normalization_layer(header, train_ds)
      encoded_numeric_col = normalization_layer(numeric_col)
      all_inputs.append(numeric_col)
      encoded_features.append(encoded_numeric_col)
    return encoded_features, all_inputs

# %%
checkpoint_callback = ModelCheckpoint("best_model.h5", monitor='val_accuracy', save_best_only=True, mode='max')

# %% [markdown]
# # Model build

# %%
def model(encoded_features,all_inputs):
    
    all_features = tf.keras.layers.concatenate(encoded_features)
    x = tf.keras.layers.Dense(32, activation="relu")(all_features)
    x = tf.keras.layers.Dropout(0.5)(x)
    output = tf.keras.layers.Dense(6)(x)

    model = tf.keras.Model(all_inputs, output)

    model.compile(optimizer='adam',
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                  metrics="accuracy",
                 )
    
    return model

# %% [markdown]
# # History build

# %%
def history(model,callbacks,train_ds,val_ds):
    

    history = model.fit(train_ds, epochs=150, validation_data=val_ds, callbacks=callbacks)

    # Get the training and validation metrics from the history
    train_accuracy = history.history['accuracy']
    val_accuracy = history.history['val_accuracy']
    train_loss = history.history['loss']
    val_loss = history.history['val_loss']

    # Plot accuracy
    plt.plot(train_accuracy, label='Training Accuracy')
    plt.plot(val_accuracy, label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

    # Plot loss
    plt.plot(train_loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()
    
    max_test_accuracy_index = history.history['val_accuracy'].index(max(history.history['val_accuracy']))

    # Get the corresponding training accuracy
    training_accuracy = history.history['accuracy'][max_test_accuracy_index]

    print('Best validation accuracy:', max(history.history['val_accuracy']))
    print('Training accuracy at the best test accuracy:', training_accuracy)
    
    return history

# %% [markdown]
# # Evaluation the Model

# %%
def run_model(ratio,callbacks):
    
    #split data
    training, test_2 = get_data_with_ratio(ratio)
    
    #change data to number
    training = change_categorical_to_number(training)
    test = change_categorical_to_number(test_2)
    
    #df to ds
    
    train_ds = df_to_dataset(training)
    val_ds = df_to_dataset(test)
    
    #encoded features
    
    encoded,inputs = encoded_features(train_ds)

    
    #set the model
    model_engine = model(encoded,inputs)
    
    #run and evaluate the model
    model_engine2 = history(model_engine,callbacks,train_ds,val_ds)
    
    #evaluate confusion matrix
    confussion_matrix(model_engine2,val_ds,test_2)

# %%
def confussion_matrix(best_model, val_ds, test_data):
    from sklearn.metrics import confusion_matrix   
    model = best_model
    
    y_pred = model.model.predict(val_ds)

    # Ubah output prediksi menjadi label kelas
    label_kelas = [0, 1, 2, 3, 4, 5]
    y_pred_label = [label_kelas[np.argmax(prediksi)] for prediksi in y_pred]

    # Test labels
    test_labels = test_data.Peruntukan

    # Calculate the confusion matrix
    cm = confusion_matrix(test_labels, y_pred_label)
    
    val_accuracy = model.history['val_accuracy']
    train_accuracy = model.history['accuracy']

    # Find the index where validation accuracy is highest
    max_val_accuracy_index = np.argmax(val_accuracy)

    # Find the index of the closest training accuracy to the maximum validation accuracy
    closest_train_accuracy_index = np.argmin([abs(i - max_val_accuracy_index) for i in range(len(train_accuracy))])

    print('Best validation accuracy:', val_accuracy[max_val_accuracy_index])
    print('Closest training accuracy to the maximum validation accuracy:', train_accuracy[closest_train_accuracy_index])




    print('Confusion matrix:')
    print(cm)
    
    confusion_matrix = cm
    
    true_positives = np.diagonal(confusion_matrix)

    # Step 3: Calculate the accuracy percentage for each class
    class_data_totals = np.sum(confusion_matrix, axis=0)
    class_accuracies = true_positives / class_data_totals * 100

    # Step 4: Calculate the overall accuracy percentage
    total_instances = np.sum(confusion_matrix)
    overall_accuracy = np.sum(true_positives) / total_instances * 100

    
 
    
    
    
    true_positives = np.diagonal(confusion_matrix)
    false_positives = np.sum(confusion_matrix, axis=0) - true_positives
    false_negatives = np.sum(confusion_matrix, axis=1) - true_positives

    # Step 3: Calculate precision, recall, and F1 score for each label
    accuracy = true_positives / np.sum(confusion_matrix, axis=1)
    precision = true_positives / (true_positives + false_positives)
    recall = true_positives / (true_positives + false_negatives)
    f1_score = 2 * (precision * recall) / (precision + recall)

    # Step 4: Calculate the total accuracy
    total_accuracy = np.sum(true_positives) / np.sum(confusion_matrix) * 100
    total_precision = np.mean(precision)
    total_recall = np.mean(recall)
    total_f1 = np.mean(f1_score)

    # Print the results
    print("Total Accuracy:", total_accuracy)
    print("Total Precision:", total_precision)
    print("Total Recall:", total_recall)
    
    print("TP for each label", true_positives)
    print("Total data for each label",  np.sum(confusion_matrix, axis=1))
    print("FP for each label", np.sum(confusion_matrix, axis=0) - true_positives)
    print("FN for each label", np.sum(confusion_matrix, axis=1) - true_positives)
    # Print the results
    print("Accuracy for each label:", class_accuracies)
    print("Precision for each label:", precision)
    print("Recall for each label:", recall)

# %% [markdown]
# # Model Evaluation

# %%
callback_1 = ModelCheckpoint("50.h5", monitor='val_accuracy', save_best_only=True, mode='max')
ratio_1 = 0.5

callback_2= ModelCheckpoint("40.h5", monitor='val_accuracy', save_best_only=True, mode='max')
ratio_2 = 0.4

callback_3= ModelCheckpoint("30.h5", monitor='val_accuracy', save_best_only=True, mode='max')
ratio_3 = 0.3

callback_4= ModelCheckpoint("20.h5", monitor='val_accuracy', save_best_only=True, mode='max')
ratio_4 = 0.2

callback_5= ModelCheckpoint("10.h5", monitor='val_accuracy', save_best_only=True, mode='max')
ratio_5 = 0.1

# %%
run_model(ratio_1, callback_1)
# Out:
# /tmp/ipykernel_531063/3426815402.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(label_train)
# /tmp/ipykernel_531063/3426815402.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data = test_data.append(label_test)
# /tmp/ipykernel_531063/3426815402.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(label_train)
# /tmp/ipykernel_531063/3426815402.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data = test_data.append(label_test)
# /tmp/ipykernel_531063/3426815402.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(label_train)
# /tmp/ipykernel_531063/3426815402.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data = test_data.append(label_test)
# /tmp/ipykernel_531063/3426815402.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(label_train)
# /tmp/ipykernel_531063/3426815402.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data = test_data.append(label_test)
# /tmp/ipykernel_531063/3426815402.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(label_train)
# /tmp/ipykernel_531063/3426815402.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data = test_data.append(label_test)
# /tmp/ipykernel_531063/3426815402.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(label_train)
# /tmp/ipykernel_531063/3426815402.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data = test_data.append(label_test)
# 2023-05-25 07:19:49.958406: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-05-25 07:19:49.958450: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-05-25 07:19:49.958474: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (gusanwa): /proc/driver/nvidia/version does not exist
# 2023-05-25 07:19:49.996648: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/150
# 13/13 [==============================] - 1s 32ms/step - loss: 1.8809 - accuracy: 0.1837 - val_loss: 2.1220 - val_accuracy: 0.1296
# Epoch 2/150
# 13/13 [==============================] - 0s 8ms/step - loss: 1.8909 - accuracy: 0.2041 - val_loss: 2.0087 - val_accuracy: 0.1481
# Epoch 3/150
# 13/13 [==============================] - 0s 8ms/step - loss: 1.8890 - accuracy: 0.1633 - val_loss: 1.8944 - val_accuracy: 0.1667
# Epoch 4/150
# 13/13 [==============================] - 0s 8ms/step - loss: 1.7342 - accuracy: 0.1633 - val_loss: 1.8013 - val_accuracy: 0.2407
# Epoch 5/150
# 13/13 [==============================] - 0s 8ms/step - loss: 1.7735 - accuracy: 0.3265 - val_loss: 1.7154 - val_accuracy: 0.2593
# Epoch 6/150
# 13/13 [==============================] - 0s 7ms/step - loss: 1.6214 - accuracy: 0.3469 - val_loss: 1.6373 - val_accuracy: 0.3333
# Epoch 7/150
# 13/13 [==============================] - 0s 7ms/step - loss: 1.6326 - accuracy: 0.3673 - val_loss: 1.5737 - val_accuracy: 0.3704
# Epoch 8/150
# 13/13 [==============================] - 0s 8ms/step - loss: 1.6131 - accuracy: 0.3265 - val_loss: 1.5247 - val_accuracy: 0.4815
# Epoch 9/150
# 13/13 [==============================] - 0s 7ms/step - loss: 1.5955 - accuracy: 0.4286 - val_loss: 1.4838 - val_accuracy: 0.5741
# Epoch 10/150
# 13/13 [==============================] - 0s 5ms/step - loss: 1
150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6092 - accuracy: 0.7347 - val_loss: 0.5205 - val_accuracy: 0.8148
# Epoch 132/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5043 - accuracy: 0.8571 - val_loss: 0.5191 - val_accuracy: 0.8148
# Epoch 133/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4718 - accuracy: 0.7959 - val_loss: 0.5188 - val_accuracy: 0.8148
# Epoch 134/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4405 - accuracy: 0.7755 - val_loss: 0.5190 - val_accuracy: 0.8148
# Epoch 135/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3714 - accuracy: 0.8776 - val_loss: 0.5182 - val_accuracy: 0.8148
# Epoch 136/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4799 - accuracy: 0.7347 - val_loss: 0.5173 - val_accuracy: 0.8148
# Epoch 137/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4828 - accuracy: 0.8367 - val_loss: 0.5166 - val_accuracy: 0.8148
# Epoch 138/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3449 - accuracy: 0.8980 - val_loss: 0.5161 - val_accuracy: 0.8148
# Epoch 139/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4129 - accuracy: 0.8367 - val_loss: 0.5159 - val_accuracy: 0.8148
# Epoch 140/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4713 - accuracy: 0.7959 - val_loss: 0.5148 - val_accuracy: 0.8148
# Epoch 141/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4521 - accuracy: 0.8163 - val_loss: 0.5123 - val_accuracy: 0.7778
# Epoch 142/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4431 - accuracy: 0.7755 - val_loss: 0.5102 - val_accuracy: 0.7778
# Epoch 143/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3799 - accuracy: 0.8571 - val_loss: 0.5085 - val_accuracy: 0.7778
# Epoch 144/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3852 - accuracy: 0.8571 - val_loss: 0.5062 - val_accuracy: 0.7778
# Epoch 145/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4786 - accuracy: 0.7755 - val_loss: 0.5043 - val_accuracy: 0.7778
# Epoch 146/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4148 - accuracy: 0.8163 - val_loss: 0.5035 - val_accuracy: 0.7963
# Epoch 147/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4594 - accuracy: 0.7959 - val_loss: 0.5027 - val_accuracy: 0.7963
# Epoch 148/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.4241 - accuracy: 0.8367 - val_loss: 0.5006 - val_accuracy: 0.7963
# Epoch 149/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4305 - accuracy: 0.8571 - val_loss: 0.5011 - val_accuracy: 0.7963
# Epoch 150/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3973 - accuracy: 0.8980 - val_loss: 0.5014 - val_accuracy: 0.7963
# Best validation accuracy: 0.8148148059844971
# Training accuracy at the best test accuracy: 0.8367347121238708
# Best validation accuracy: 0.8148148059844971
# Closest training accuracy to the maximum validation accuracy: 0.8367347121238708
# Confusion matrix:
# [[12  0  0  0  0  0]
#  [ 0  0  0  2  0  2]
#  [ 0  0  3  0  0  0]
#  [ 0  0  0 20  0  0]
#  [ 0  0  0  0  4  3]
#  [ 0  0  0  0  4  4]]
# Total Accuracy: 79.62962962962963
# Total Precision: nan
# Total Recall: 0.6785714285714285
# TP for each label [12  0  3 20  4  4]
# Total data for each label [12  4  3 20  7  8]
# FP for each label [0 0 0 2 4 5]
# FN for each label [0 4 0 0 3 4]
# Accuracy for each label: [100.                  nan 100.          90.90909091  50.
#   44.44444444]
# Precision for each label: [1.                nan 1.         0.90909091 0.5        0.44444444]
# Recall for each label: [1.         0.         1.         1.         0.57142857 0.5       ]
# /tmp/ipykernel_531063/2608161719.py:41: RuntimeWarning: invalid value encountered in divide
#   class_accuracies = true_positives / class_data_totals * 100
# /tmp/ipykernel_531063/2608161719.py:58: RuntimeWarning: invalid value encountered in divide
#   precision = true_positives / (true_positives + false_positives)

# %%
run_model(ratio_2, callback_2)
# Out:
# /tmp/ipykernel_531063/3426815402.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(label_train)
# /tmp/ipykernel_531063/3426815402.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data = test_data.append(label_test)
# /tmp/ipykernel_531063/3426815402.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(label_train)
# /tmp/ipykernel_531063/3426815402.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data = test_data.append(label_test)
# /tmp/ipykernel_531063/3426815402.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(label_train)
# /tmp/ipykernel_531063/3426815402.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data = test_data.append(label_test)
# /tmp/ipykernel_531063/3426815402.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(label_train)
# /tmp/ipykernel_531063/3426815402.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data = test_data.append(label_test)
# /tmp/ipykernel_531063/3426815402.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(label_train)
# /tmp/ipykernel_531063/3426815402.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data = test_data.append(label_test)
# /tmp/ipykernel_531063/3426815402.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(label_train)
# /tmp/ipykernel_531063/3426815402.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data = test_data.append(label_test)
150
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5156 - accuracy: 0.7949 - val_loss: 0.6830 - val_accuracy: 0.7812
# Epoch 137/150
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3806 - accuracy: 0.8718 - val_loss: 0.6787 - val_accuracy: 0.7812
# Epoch 138/150
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3379 - accuracy: 0.9231 - val_loss: 0.6779 - val_accuracy: 0.7500
# Epoch 139/150
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4071 - accuracy: 0.8974 - val_loss: 0.6774 - val_accuracy: 0.7656
# Epoch 140/150
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3853 - accuracy: 0.8718 - val_loss: 0.6780 - val_accuracy: 0.7656
# Epoch 141/150
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4087 - accuracy: 0.8462 - val_loss: 0.6797 - val_accuracy: 0.7656
# Epoch 142/150
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5363 - accuracy: 0.8462 - val_loss: 0.6834 - val_accuracy: 0.7812
# Epoch 143/150
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4468 - accuracy: 0.8974 - val_loss: 0.6804 - val_accuracy: 0.7812
# Epoch 144/150
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4468 - accuracy: 0.8462 - val_loss: 0.6783 - val_accuracy: 0.7812
# Epoch 145/150
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3543 - accuracy: 0.9231 - val_loss: 0.6768 - val_accuracy: 0.7812
# Epoch 146/150
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4557 - accuracy: 0.7436 - val_loss: 0.6798 - val_accuracy: 0.7812
# Epoch 147/150
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4010 - accuracy: 0.8974 - val_loss: 0.6838 - val_accuracy: 0.7500
# Epoch 148/150
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3479 - accuracy: 0.8974 - val_loss: 0.6827 - val_accuracy: 0.7500
# Epoch 149/150
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4311 - accuracy: 0.8974 - val_loss: 0.6828 - val_accuracy: 0.7656
# Epoch 150/150
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3460 - accuracy: 0.8718 - val_loss: 0.6851 - val_accuracy: 0.7656
# Best validation accuracy: 0.78125
# Training accuracy at the best test accuracy: 0.8205128312110901
# Best validation accuracy: 0.78125
# Closest training accuracy to the maximum validation accuracy: 0.8205128312110901
# Confusion matrix:
# [[14  0  0  0  0  0]
#  [ 0  0  0  3  0  2]
#  [ 0  0  3  0  0  0]
#  [ 1  0  0 23  0  0]
#  [ 0  0  0  3  6  0]
#  [ 0  0  0  2  4  3]]
# Total Accuracy: 76.5625
# Total Precision: nan
# Total Recall: 0.6597222222222222
# TP for each label [14  0  3 23  6  3]
# Total data for each label [14  5  3 24  9  9]
# FP for each label [1 0 0 8 4 2]
# FN for each label [0 5 0 1 3 6]
# Accuracy for each label: [ 93.33333333          nan 100.          74.19354839  60.
#   60.        ]
# Precision for each label: [0.93333333        nan 1.         0.74193548 0.6        0.6       ]
# Recall for each label: [1.         0.         1.         0.95833333 0.66666667 0.33333333]
# /tmp/ipykernel_531063/2608161719.py:41: RuntimeWarning: invalid value encountered in divide
#   class_accuracies = true_positives / class_data_totals * 100
# /tmp/ipykernel_531063/2608161719.py:58: RuntimeWarning: invalid value encountered in divide
#   precision = true_positives / (true_positives + false_positives)

# %%
run_model(ratio_3, callback_3)
# Out:
# /tmp/ipykernel_531063/3426815402.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(label_train)
# /tmp/ipykernel_531063/3426815402.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data = test_data.append(label_test)
# /tmp/ipykernel_531063/3426815402.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(label_train)
# /tmp/ipykernel_531063/3426815402.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data = test_data.append(label_test)
# /tmp/ipykernel_531063/3426815402.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(label_train)
# /tmp/ipykernel_531063/3426815402.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data = test_data.append(label_test)
# /tmp/ipykernel_531063/3426815402.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(label_train)
# /tmp/ipykernel_531063/3426815402.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data = test_data.append(label_test)
# /tmp/ipykernel_531063/3426815402.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(label_train)
# /tmp/ipykernel_531063/3426815402.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data = test_data.append(label_test)
# /tmp/ipykernel_531063/3426815402.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(label_train)
# /tmp/ipykernel_531063/3426815402.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data = test_data.append(label_test)
# 7/7 [==============================] - 0s 10ms/step - loss: 1.2673 - accuracy: 0.6786 - val_loss: 1.3328 - val_accuracy: 0.5200
# Epoch 27/150
# 7/7 [==============================] - 0s 10ms/step - loss: 1.3192 - accuracy: 0.6071 - val_loss: 1.3189 - val_accuracy: 0.5200
# Epoch 28/150
# 7/7 [==============================] - 0s 10ms/step - loss: 1.2268 - accuracy: 0.6429 - val_loss: 1.3060 - val_accuracy: 0.5200
# Epoch 29/150
# 7/7 [==============================] - 0s 10ms/step - loss: 1.1822 - accuracy: 0.6429 - val_loss: 1.2978 - val_accuracy: 0.5200
# Epoch 30/150
# 7/7 [==============================] - 0s 10ms/step - loss: 1.2475 - accuracy: 0.6429 - val_loss: 1.2846 - val_accuracy: 0.5200
# Epoch 31/150
# 7/7 [==============================] - 0s 10ms/step - loss: 1.1913 - accuracy: 0.6071 - val_loss: 1.2680 - val_accuracy: 0.5200
# Epoch 32/150
# 7/7 [==============================] - 0s 10ms/step - loss: 1.1527 - accuracy: 0.7143 - val_loss: 1.2549 - val_accuracy: 0.5200
# Epoch 33/150
# 7/7 [==============================] - 0s 14ms/step - loss: 1.1408 - accuracy: 0.6429 - val_loss: 1.2410 - val_accuracy: 0.5200
# Epoch 34/150
# 7/7 [==============================] - 0s 15ms/step - loss: 1.2010 - accuracy: 0.6429 - val_loss: 1.2334 - val_accuracy: 0.5200
# Epoch 35/150
# 7/7 [==============================] - 0s 16ms/step - loss: 1.2036 - accuracy: 0.7143 - val_loss: 1.2179 - val_accuracy: 0.5467
# Epoch 36/150
# 7/7 [==============================] - 0s 11ms/step - loss: 1.1397 - accuracy: 0.7143 - val_loss: 1.2077 - val_accuracy: 0.5467
# Epoch 37/150
# 7/7 [==============================] - 0s 11ms/step - loss: 1.0868 - accuracy: 0.7143 - val_loss: 1.1970 - val_accuracy: 0.5467
# Epoch 38/150
# 7/7 [==============================] - 0s 11ms/step - loss: 1.0463 - accuracy: 0.6429 - val_loss: 1.1832 - val_accuracy: 0.5467
# Epoch 39/150
# 7/7 [==============================] - 0s 11ms/step - loss: 1.0821 - accuracy: 0.7143 - val_loss: 1.1672 - val_accuracy: 0.5467
# Epoch 40/150
# 7/7 [==============================] - 0s 11ms/step - loss: 1.0177 - accuracy: 0.7857 - val_loss: 1.1535 - val_accuracy: 0.5467
# Epoch 41/150
# 7/7 [==============================] - 0s 10ms/step - loss: 1.0193 - accuracy: 0.7143 - val_loss: 1.1424 - val_accuracy: 0.5467
# Epoch 42/150
# 7/7 [==============================] - 0s 10ms/step - loss: 1.0237 - accuracy: 0.7143 - val_loss: 1.1394 - val_accuracy: 0.5467
# Epoch 43/150
# 7/7 [==============================] - 0s 10ms/step - loss: 0.9687 - accuracy: 0.7857 - val_loss: 1.1309 - val_accuracy: 0.5467
# Epoch 44/150
# 7/7 [==============================] - 0s 16ms/step - loss: 0.9664 - accuracy: 0.6429 - val_loss: 1.1201 - val_accuracy: 0.5600
# Epoch 45/150
# 7/7 [==============================] - 0s 11ms/step - loss: 1.0889 - accuracy: 0.6071 - val_loss: 1.1146 - val_accuracy: 0.5600
# Epoch 46/150
# 7/7 [==============================] - 0s 11ms/step - loss: 0.9418 - accuracy: 0.7500 - val_loss: 1.1061 - val_accuracy: 0.5600
# Epoch 47/150
# 7/7 [==============================] - 0s 11ms/step - loss: 0.8629 - accuracy: 0.7857 - val_loss: 1.0965 - val_accuracy: 0.5600
# Epoch 48/150
# 7/7 [==============================] - 0s 11ms/step - loss: 0.8935 - accuracy: 0.8214 - val_loss: 1.0842 - val_accuracy: 0.5600
# Epoch 49/150
# 7/7 [==============================] - 0s 11ms/step - loss: 0.9309 - accuracy: 0.7500 - val_loss: 1.0757 - val_accuracy: 0.5600
# Epoch 50/150
# 7/7 [==============================] - 0s 16ms/step - loss: 0.9297 - accuracy: 0.7500 - val_loss: 1.0658 - val_accuracy: 0.5733
# Epoch 51/150
# 7/7 [==============================] - 0s 11ms/step - loss: 0.8922 - accuracy: 0.6786 - val_loss: 1.0583 - val_accuracy: 0.5733
# Epoch 52/150
# 7/7 [==============================] - 0s 11ms/step - loss: 0.9249 - accuracy: 0.7857 - val_loss: 1.0521 - val_accuracy: 0.5733
# Epoch 53/150
# 7/7 [==============================] - 0s 11ms/step - loss: 0.
150
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5635 - accuracy: 0.8214 - val_loss: 0.8240 - val_accuracy: 0.6533
# Epoch 141/150
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5460 - accuracy: 0.9286 - val_loss: 0.8242 - val_accuracy: 0.6533
# Epoch 142/150
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5041 - accuracy: 0.8929 - val_loss: 0.8292 - val_accuracy: 0.6533
# Epoch 143/150
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4664 - accuracy: 0.8571 - val_loss: 0.8269 - val_accuracy: 0.6533
# Epoch 144/150
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5957 - accuracy: 0.7857 - val_loss: 0.8231 - val_accuracy: 0.6533
# Epoch 145/150
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3801 - accuracy: 0.8929 - val_loss: 0.8207 - val_accuracy: 0.6533
# Epoch 146/150
# 7/7 [==============================] - 0s 11ms/step - loss: 0.4424 - accuracy: 0.7857 - val_loss: 0.8173 - val_accuracy: 0.6533
# Epoch 147/150
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5430 - accuracy: 0.7857 - val_loss: 0.8160 - val_accuracy: 0.6533
# Epoch 148/150
# 7/7 [==============================] - 0s 11ms/step - loss: 0.4190 - accuracy: 0.8571 - val_loss: 0.8134 - val_accuracy: 0.6667
# Epoch 149/150
# 7/7 [==============================] - 0s 10ms/step - loss: 0.5585 - accuracy: 0.8929 - val_loss: 0.8107 - val_accuracy: 0.6667
# Epoch 150/150
# 7/7 [==============================] - 0s 10ms/step - loss: 0.4806 - accuracy: 0.8571 - val_loss: 0.8092 - val_accuracy: 0.6667
# Best validation accuracy: 0.6666666865348816
# Training accuracy at the best test accuracy: 0.75
# Best validation accuracy: 0.6666666865348816
# Closest training accuracy to the maximum validation accuracy: 0.75
# Confusion matrix:
# [[17  0  0  0  0  0]
#  [ 0  0  0  3  1  1]
#  [ 0  0  0  4  0  0]
#  [ 0  0  0 26  2  0]
#  [ 0  0  0  3  7  0]
#  [ 0  0  0  4  7  0]]
# Total Accuracy: 66.66666666666666
# Total Precision: nan
# Total Recall: 0.4380952380952381
# TP for each label [17  0  0 26  7  0]
# Total data for each label [17  5  4 28 10 11]
# FP for each label [ 0  0  0 14 10  1]
# FN for each label [ 0  5  4  2  3 11]
# Accuracy for each label: [100.                  nan          nan  65.          41.17647059
#    0.        ]
# Precision for each label: [1.                nan        nan 0.65       0.41176471 0.        ]
# Recall for each label: [1.         0.         0.         0.92857143 0.7        0.        ]
# /tmp/ipykernel_531063/2608161719.py:41: RuntimeWarning: invalid value encountered in divide
#   class_accuracies = true_positives / class_data_totals * 100
# /tmp/ipykernel_531063/2608161719.py:58: RuntimeWarning: invalid value encountered in divide
#   precision = true_positives / (true_positives + false_positives)
# /tmp/ipykernel_531063/2608161719.py:60: RuntimeWarning: invalid value encountered in divide
#   f1_score = 2 * (precision * recall) / (precision + recall)

# %%
run_model(ratio_4, callback_4)
# Out:
# /tmp/ipykernel_531063/3426815402.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(label_train)
# /tmp/ipykernel_531063/3426815402.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data = test_data.append(label_test)
# /tmp/ipykernel_531063/3426815402.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(label_train)
# /tmp/ipykernel_531063/3426815402.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data = test_data.append(label_test)
# /tmp/ipykernel_531063/3426815402.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(label_train)
# /tmp/ipykernel_531063/3426815402.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data = test_data.append(label_test)
# /tmp/ipykernel_531063/3426815402.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(label_train)
# /tmp/ipykernel_531063/3426815402.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data = test_data.append(label_test)
# /tmp/ipykernel_531063/3426815402.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(label_train)
# /tmp/ipykernel_531063/3426815402.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data = test_data.append(label_test)
# /tmp/ipykernel_531063/3426815402.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(label_train)
# /tmp/ipykernel_531063/3426815402.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data = test_data.append(label_test)
# Epoch 1/150
# 5/5 [==============================] - 1s 62ms/step - loss: 1.7763 - accuracy: 0.3333 - val_loss: 2.0700 - val_accuracy: 0.3647
# Epoch 2/150
# 5/5 [==============================] - 0s 16ms/step - loss: 1.8441 - accuracy: 0.2778 - val_loss: 2.0440 - val_accuracy: 0.3647
# Epoch 3/150
# 5/5 [==============================] - 0s 16ms/step - loss: 1.8073 - accuracy: 0.2778 - val_loss: 2.0231 - val_accuracy: 0.3647
# Epoch 4/150
# 5/5 [==============================] - 0s 16ms/step - loss: 1.7545 - accuracy: 0.3889 - val_loss: 1.9973 - val_accuracy: 0.3647
# Epoch 5/150
# 5/5 [==============================] - 0s 16ms/step - loss: 1.0572 - accuracy: 0.7222 - val_loss: 1.3388 - val_accuracy: 0.6471
# Epoch 48/150
# 5/5 [==============================] - 0s 22ms/step - loss: 1.1161 - accuracy: 0.7222 - val_loss: 1.3324 - val_accuracy: 0.6588
# Epoch 49/150
# 5/5 [==============================] - 0s 23ms/step - loss: 1.1346 - accuracy: 0.6667 - val_loss: 1.3259 - val_accuracy: 0.6706
# Epoch 50/150
# 5/5 [==============================] - 0s 27ms/step - loss: 1.1283 - accuracy: 0.6111 - val_loss: 1.3201 - val_accuracy: 0.6824
# Epoch 51/150
# 5/5 [==============================] - 0s 20ms/step - loss: 1.0704 - accuracy: 0.7778 - val_loss: 1.3137 - val_accuracy: 0.6824
# Epoch 52/150
# 5/5 [==============================] - 0s 19ms/step - loss: 1.1225 - accuracy: 0.6111 - val_loss: 1.3078 - val_accuracy: 0.6824
# Epoch 53/150
# 5/5 [==============================] - 0s 18ms/step - loss: 1.1907 - accuracy: 0.6667 - val_loss: 1.3018 - val_accuracy: 0.6706
# Epoch 54/150
# 5/5 [==============================] - 0s 17ms/step - loss: 0.9887 - accuracy: 0.7222 - val_loss: 1.2951 - val_accuracy: 0.6824
# Epoch 55/150
# 5/5 [==============================] - 0s 15ms/step - loss: 1.2725 - accuracy: 0.5556 - val_loss: 1.2893 - val_accuracy: 0.6824
# Epoch 56/150
# 5/5 [==============================] - 0s 15ms/step - loss: 1.0749 - accuracy: 0.6111 - val_loss: 1.2840 - val_accuracy: 0.6824
# Epoch 57/150
# 5/5 [==============================] - 0s 16ms/step - loss: 0.9198 - accuracy: 0.6667 - val_loss: 1.2789 - val_accuracy: 0.6824
# Epoch 58/150
# 5/5 [==============================] - 0s 19ms/step - loss: 1.0079 - accuracy: 0.7222 - val_loss: 1.2742 - val_accuracy: 0.6824
# Epoch 59/150
# 5/5 [==============================] - 0s 25ms/step - loss: 0.9534 - accuracy: 0.6667 - val_loss: 1.2697 - val_accuracy: 0.6706
# Epoch 60/150
# 5/5 [==============================] - 0s 18ms/step - loss: 1.1890 - accuracy: 0.6111 - val_loss: 1.2657 - val_accuracy: 0.6471
# Epoch 61/150
# 5/5 [==============================] - 0s 14ms/step - loss: 1.0316 - accuracy: 0.7778 - val_loss: 1.2616 - val_accuracy: 0.6471
# Epoch 62/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.9633 - accuracy: 0.7778 - val_loss: 1.2567 - val_accuracy: 0.6471
# Epoch 63/150
# 5/5 [==============================] - 0s 13ms/step - loss: 1.0662 - accuracy: 0.6667 - val_loss: 1.2520 - val_accuracy: 0.6471
# Epoch 64/150
# 5/5 [==============================] - 0s 13ms/step - loss: 0.9369 - accuracy: 0.7222 - val_loss: 1.2462 - val_accuracy: 0.6471
# Epoch 65/150
# 5/5 [==============================] - 0s 17ms/step - loss: 0.9331 - accuracy: 0.8889 - val_loss: 1.2410 - val_accuracy: 0.6471
# Epoch 66/150
# 5/5 [==============================] - 0s 17ms/step - loss: 1.0065 - accuracy: 0.6111 - val_loss: 1.2344 - val_accuracy: 0.6353
# Epoch 67/150
# 5/5 [==============================] - 0s 17ms/step - loss: 1.0350 - accuracy: 0.6111 - val_loss: 1.2271 - val_accuracy: 0.6471
# Epoch 68/150
# 5/5 [==============================] - 0s 17ms/step - loss: 0.9671 - accuracy: 0.7222 - val_loss: 1.2198 - val_accuracy: 0.6471
# Epoch 69/150
# 5/5 [==============================] - 0s 17ms/step - loss: 1.0294 - accuracy: 0.6111 - val_loss: 1.2126 - val_accuracy: 0.6471
# Epoch 70/150
# 5/5 [==============================] - 0s 15ms/step - loss: 1.2152 - accuracy: 0.5556 - val_loss: 1.2059 - val_accuracy: 0.6471
# Epoch 71/150
# 5/5 [==============================] - 0s 14ms/step - loss: 1.0171 - accuracy: 0.7778 - val_loss: 1.2007 - val_accuracy: 0.6471
# Epoch 72/150
# 5/5 [==============================] - 0s 14ms/step - loss: 1.0745 - accuracy: 0.5000 - val_loss: 1.1961 - val_accuracy: 0.6588
# Epoch 73/150
# 5/5 [==============================] - 0s 14ms/step - loss: 0.9289 - accuracy: 0.8333 - val_loss: 1.1913 - val_accuracy: 0.6706
# Epoch 74/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.9178 - accuracy: 0.7222 - val_loss: 1.1864 - val_accuracy: 0.6706
# Epoch 75/150
# 5/5 [==============================] - 0s 17ms/step - loss: 0.9155 - accuracy: 0.7778 - val_loss: 1.1800 - val_accuracy: 0.6706
# Epoch 76/150
# 5/5 [==============================] - 0s 19ms/step - loss: 0.8715 - accuracy: 0.7778 - val_loss: 1.1742 - val_accuracy: 0.6706
# Epoch 77/150
# 5/5 [==============================] - 0s 22ms/step - loss: 0.8805 - accuracy: 0.6667 - val_loss: 1.1693 - val_accuracy: 0.6706
# Epoch 78/150
# 5/5 [==============================] - 0s 16ms/step - loss: 1.0281 - accuracy: 0.6667 - val_loss: 1.1604 - val_accuracy: 0.6706
# Epoch 79/150
# 5/5 [==============================] - 0s 19ms/step - loss: 1.0031 - accuracy: 0.7222 - val_loss: 1.1539 - val_accuracy: 0.6706
# Epoch 80/150
# 5/5 [==============================] - 0s 18ms/step - loss: 1.0440 - accuracy: 0.6667 - val_loss: 1.1467 - val_accuracy: 0.6706
# Epoch 81/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.8447 - accuracy: 0.7778 - val_loss: 1.1409 - val_accuracy: 0.6706
# Epoch 82/150
# 5/5 [==============================] - 0s 19ms/step - loss: 0.8452 - accuracy: 0.8889 - val_loss: 1.1357 - val_accuracy: 0.6706
# Epoch 83/150
# 5/5 [==============================] - 0s 17ms/step - loss: 0.9046 - accuracy: 0.7222 - val_loss: 1.1304 - val_accuracy: 0.6706
# Epoch 84/150
# 5/5 [==============================] - 0s 17ms/step - loss: 0.8638 - accuracy: 0.7778 - val_loss: 1.1262 - val_accuracy: 0.6824
# Epoch 85/150
# 5/5 [==============================] - 0s 16ms/step - loss: 0.8509 - accuracy: 0.6667 - val_loss: 1.1207 - val_accuracy: 0.6706
# Epoch 86/150
# 5/5 [==============================] - 0s 16ms/step - loss: 0.9102 - accuracy: 0.7222 - val_loss: 1.1164 - val_accuracy: 0.6706
# Epoch 87/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.8745 - accuracy: 0.6667 - val_loss: 1.1114 - val_accuracy: 0.6706
# Epoch 88/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.9380 - accuracy: 0.7778 - val_loss: 1.1052 - val_accuracy: 0.6706
# Epoch 89/150
# 5/5 [==============================] - 0s 15ms/step - loss: 1.0113 - accuracy: 0.5556 - val_loss: 1.1000 - val_accuracy: 0.6706
# Epoch 90/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.7747 - accuracy: 0.7778 - val_loss: 1.0959 - val_accuracy: 0.6706
# Epoch 91/150
# 5/5 [==============================] - 0s 16ms/step - loss: 0.7697 - accuracy: 0.7222 - val_loss: 1.0933 - val_accuracy: 0.6706
# Epoch 92/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.8763 - accuracy: 0.7222 - val_loss: 1.0917 - val_accuracy: 0.6706
# Epoch 93/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.9263 - accuracy: 0.7778 - val_loss: 1.0902 - val_accuracy: 0.6706
# Epoch 94/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.7227 - accuracy: 0.8889 - val_loss: 1.0883 - val_accuracy: 0.6706
# Epoch 95/150
# 5/5 [==============================] - 0s 21ms/step - loss: 0.6929 - accuracy: 0.7778 - val_loss: 1.0866 - val_accuracy: 0.6706
# Epoch 96/150
# 5/5 [==============================] - 0s 14ms/step - loss: 0.7801 - accuracy: 0.7778 - val_loss: 1.0848 - val_accuracy: 0.6706
# Epoch 97/150
# 5/5 [==============================] - 0s 16ms/step - loss: 0.7159 - accuracy: 0.8889 - val_loss: 1.0840 - val_accuracy: 0.6706
# Epoch 98/150
# 5/5 [==============================] - 0s 14ms/step - loss: 0.7243 - accuracy: 0.8333 - val_loss: 1.0829 - val_accuracy: 0.6706
# Epoch 99/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.8113 - accuracy: 0.7222 - val_loss: 1.0803 - val_accuracy: 0.6706
# Epoch 100/150
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6787 - accuracy: 0.7778 - val_loss: 1.0739 - val_accuracy: 0.6824
# Epoch 101/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.7979 - accuracy: 0.7222 - val_loss: 1.0690 - val_accuracy: 0.6824
# Epoch 102/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.8549 - accuracy: 0.6667 - val_loss: 1.0661 - val_accuracy: 0.6824
# Epoch 103/150
# 5/5 [==============================] - 0s 16ms/step - loss: 0.7294 - accuracy: 0.8333 - val_loss: 1.0638 - val_accuracy: 0.6824
# Epoch 104/150
# 5/5 [==============================] - 0s 16ms/step - loss: 0.8428 - accuracy: 0.7222 - val_loss: 1.0624 - val_accuracy: 0.6824
# Epoch 105/150
# 5/5 [==============================] - 0s 18ms/step - loss: 0.6110 - accuracy: 0.8889 - val_loss: 1.0609 - val_accuracy: 0.6824
# Epoch 106/150
# 5/5 [==============================] - 0s 18ms/step - loss: 0.5461 - accuracy: 0.8333 - val_loss: 1.0587 - val_accuracy: 0.6824
# Epoch 107/150
# 5/5 [==============================] - 0s 19ms/step - loss: 0.7433 - accuracy: 0.7778 - val_loss: 1.0567 - val_accuracy: 0.6824
# Epoch 108/150
# 5/5 [==============================] - 0s 23ms/step - loss: 0.6912 - accuracy: 0.7222 - val_loss: 1.0553 - val_accuracy: 0.6824
# Epoch 109/150
# 5/5 [==============================] - 0s 18ms/step - loss: 0.7324 - accuracy: 0.7778 - val_loss: 1.0540 - val_accuracy: 0.6824
# Epoch 110/150
# 5/5 [==============================] - 0s 18ms/step - loss: 0.9585 - accuracy: 0.7222 - val_loss: 1.0522 - val_accuracy: 0.6824
# Epoch 111/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.8111 - accuracy: 0.7778 - val_loss: 1.0517 - val_accuracy: 0.6824
# Epoch 112/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6609 - accuracy: 0.8333 - val_loss: 1.0495 - val_accuracy: 0.6824
# Epoch 113/150
# 5/5 [==============================] - 0s 14ms/step - loss: 0.7605 - accuracy: 0.7222 - val_loss: 1.0485 - val_accuracy: 0.6824
# Epoch 114/150
# 5/5 [==============================] - 0s 14ms/step - loss: 0.7107 - accuracy: 0.8333 - val_loss: 1.0456 - val_accuracy: 0.6824
# Epoch 115/150
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6922 - accuracy: 0.8333 - val_loss: 1.0435 - val_accuracy: 0.6824
# Epoch 116/150
# 5/5 [==============================] - 0s 18ms/step - loss: 0.8152 - accuracy: 0.6667 - val_loss: 1.0427 - val_accuracy: 0.6824
# Epoch 117/150
# 5/5 [==============================] - 0s 16ms/step - loss: 0.8890 - accuracy: 0.7222 - val_loss: 1.0425 - val_accuracy: 0.6824
# Epoch 118/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5777 - accuracy: 0.8333 - val_loss: 1.0423 - val_accuracy: 0.6706
# Epoch 119/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5754 - accuracy: 0.8889 - val_loss: 1.0419 - val_accuracy: 0.6706
# Epoch 120/150
# 5/5 [==============================] - 0s 14ms/step - loss: 0.7557 - accuracy: 0.6667 - val_loss: 1.0415 - val_accuracy: 0.6706
# Epoch 121/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.7284 - accuracy: 0.7778 - val_loss: 1.0401 - val_accuracy: 0.6706
# Epoch 122/150
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6993 - accuracy: 0.7778 - val_loss: 1.0398 - val_accuracy: 0.6706
# Epoch 123/150
# 5/5 [==============================] - 0s 19ms/step - loss: 0.6925 - accuracy: 0.7778 - val_loss: 1.0411 - val_accuracy: 0.6706
# Epoch 124/150
# 5/5 [==============================] - 0s 19ms/step - loss: 0.7180 - accuracy: 0.7778 - val_loss: 1.0413 - val_accuracy: 0.6706
# Epoch 125/150
# 5/5 [==============================] - 0s 18ms/step - loss: 0.6990 - accuracy: 0.7222 - val_loss: 1.0429 - val_accuracy: 0.6706
# Epoch 126/150
# 5/5 [==============================] - 0s 16ms/step - loss: 0.7641 - accuracy: 0.7778 - val_loss: 1.0425 - val_accuracy: 0.6824
# Epoch 127/150
# 5/5 [==============================] - 0s 16ms/step - loss: 0.7802 - accuracy: 0.7222 - val_loss: 1.0430 - val_accuracy: 0.6824
# Epoch 128/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5058 - accuracy: 0.8889 - val_loss: 1.0436 - val_accuracy: 0.6824
# Epoch 129/150
# 5/5 [==============================] - 0s 14ms/step - loss: 0.9160 - accuracy: 0.6667 - val_loss: 1.0440 - val_accuracy: 0.6824
# Epoch 130/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6376 - accuracy: 0.8889 - val_loss: 1.0446 - val_accuracy: 0.6824
# Epoch 131/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6800 - accuracy: 0.7222 - val_loss: 1.0455 - val_accuracy: 0.6824
# Epoch 132/150
# 5/5 [==============================] - 0s 14ms/step - loss: 0.7599 - accuracy: 0.7778 - val_loss: 1.0460 - val_accuracy: 0.6824
# Epoch 133/150
# 5/5 [==============================] - 0s 13ms/step - loss: 0.5699 - accuracy: 0.8333 - val_loss: 1.0460 - val_accuracy: 0.6824
# Epoch 134/150
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6673 - accuracy: 0.8333 - val_loss: 1.0456 - val_accuracy: 0.6824
# Epoch 135/150
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6007 - accuracy: 0.8333 - val_loss: 1.0453 - val_accuracy: 0.6824
# Epoch 136/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.7103 - accuracy: 0.6667 - val_loss: 1.0451 - val_accuracy: 0.6824
# Epoch 137/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5831 - accuracy: 0.7778 - val_loss: 1.0457 - val_accuracy: 0.6824
# Epoch 138/150
# 5/5 [==============================] - 0s 21ms/step - loss: 0.8000 - accuracy: 0.8333 - val_loss: 1.0470 - val_accuracy: 0.6941
# Epoch 139/150
# 5/5 [==============================] - 0s 13ms/step - loss: 0.5823 - accuracy: 0.8333 - val_loss: 1.0487 - val_accuracy: 0.6941
# Epoch 140/150
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6857 - accuracy: 0.7778 - val_loss: 1.0497 - val_accuracy: 0.6941
# Epoch 141/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5927 - accuracy: 0.8889 - val_loss: 1.0474 - val_accuracy: 0.6824
# Epoch 142/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.8650 - accuracy: 0.7222 - val_loss: 1.0438 - val_accuracy: 0.6824
# Epoch 143/150
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6040 - accuracy: 0.8889 - val_loss: 1.0414 - val_accuracy: 0.6824
# Epoch 144/150
# 5/5 [==============================] - 0s 14ms/step - loss: 0.4937 - accuracy: 0.7778 - val_loss: 1.0404 - val_accuracy: 0.6824
# Epoch 145/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5938 - accuracy: 0.9444 - val_loss: 1.0403 - val_accuracy: 0.6941
# Epoch 146/150
# 5/5 [==============================] - 0s 24ms/step - loss: 0.6340 - accuracy: 0.7222 - val_loss: 1.0397 - val_accuracy: 0.7059
# Epoch 147/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5759 - accuracy: 0.8889 - val_loss: 1.0392 - val_accuracy: 0.7059
# Epoch 148/150
# 5/5 [==============================] - 0s 23ms/step - loss: 0.7941 - accuracy: 0.7222 - val_loss: 1.0404 - val_accuracy: 0.7176
# Epoch 149/150
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5477 - accuracy: 0.7222 - val_loss: 1.0410 - val_accuracy: 0.7176
# Epoch 150/150
# 5/5 [==============================] - 0s 14ms/step - loss: 0.4616 - accuracy: 0.8333 - val_loss: 1.0407 - val_accuracy: 0.7059
# Best validation accuracy: 0.7176470756530762
# Training accuracy at the best test accuracy: 0.7222222089767456
# Best validation accuracy: 0.7176470756530762
# Closest training accuracy to the maximum validation accuracy: 0.7222222089767456
# Confusion matrix:
# [[15  0  0  4  0  0]
#  [ 0  0  0  3  0  3]
#  [ 0  0  4  0  0  0]
#  [ 0  0  0 32  0  0]
#  [ 0  0  0  2  0 10]
#  [ 0  0  0  2  1  9]]
# Total Accuracy: 70.58823529411765
# Total Precision: nan
# Total Recall: 0.5899122807017544
# TP for each label [15  0  4 32  0  9]
# Total data for each label [19  6  4 32 12 12]
# FP for each label [ 0  0  0 11  1 13]
# FN for each label [ 4  6  0  0 12  3]
# Accuracy for each label: [100.                  nan 100.          74.41860465   0.
#   40.90909091]
# Precision for each label: [1.                nan 1.         0.74418605 0.         0.40909091]
# Recall for each label: [0.78947368 0.         1.         1.         0.         0.75      ]
# /tmp/ipykernel_531063/2608161719.py:41: RuntimeWarning: invalid value encountered in divide
#   class_accuracies = true_positives / class_data_totals * 100
# /tmp/ipykernel_531063/2608161719.py:58: RuntimeWarning: invalid value encountered in divide
#   precision = true_positives / (true_positives + false_positives)
# /tmp/ipykernel_531063/2608161719.py:60: RuntimeWarning: invalid value encountered in divide
#   f1_score = 2 * (precision * recall) / (precision + recall)

# %%
run_model(ratio_5, callback_5)
# Out:
# /tmp/ipykernel_531063/3426815402.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   train_data = train_data.append(label_train)
# /tmp/ipykernel_531063/3426815402.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_data = test_data.append(label_test)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 run_model(ratio_5, callback_5)
#
# Input In [11], in run_model(ratio, callbacks)
#       1 def run_model(ratio,callbacks):
#       2
#       3     #split data
# ----> 4     training, test_2 = get_data_with_ratio(ratio)
#       6     #change data to number
#       7     training = change_categorical_to_number(training)
#
# Input In [3], in get_data_with_ratio(ratio)
#      24 # Memisahkan data pelatihan dan pengujian berdasarkan rasio
#      25 for label in peruntukan_data:
# ---> 26     label_train, label_test = train_test_split(peruntukan_data[label], test_size=1-ratio, random_state=42, shuffle = False)
#      27     train_data = train_data.append(label_train)
#      28     test_data = test_data.append(label_test)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/model_selection/_split.py:2433, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2430 arrays = indexable(*arrays)
#    2432 n_samples = _num_samples(arrays[0])
# -> 2433 n_train, n_test = _validate_shuffle_split(
#    2434     n_samples, test_size, train_size, default_test_size=0.25
#    2435 )
#    2437 if shuffle is False:
#    2438     if stratify is not None:
#
# File ~/.local/lib/python3.10/site-packages/sklearn/model_selection/_split.py:2111, in _validate_shuffle_split(n_samples, test_size, train_size, default_test_size)
#    2108 n_train, n_test = int(n_train), int(n_test)
#    2110 if n_train == 0:
# -> 2111     raise ValueError(
#    2112         "With n_samples={}, test_size={} and train_size={}, the "
#    2113         "resulting train set will be empty. Adjust any of the "
#    2114         "aforementioned parameters.".format(n_samples, test_size, train_size)
#    2115     )
#    2117 return n_train, n_test
#
# ValueError: With n_samples=7, test_size=0.9 and train_size=None, the resulting train set will be empty. Adjust any of the aforementioned parameters.

# %% [markdown]
# #

# %% [markdown]
# # Print the method

# %%
training, test_2 = get_data_with_ratio(0.5)
training.head()

# %%
test_2.head()

# %%
#split data

    
    #change data to number
training = change_categorical_to_number(training)
test = change_categorical_to_number(test_2)

training.head()

# %%
test_2.head()

# %%
train_ds = df_to_dataset(training)
val_ds = df_to_dataset(test)
    
    #encoded features
dataset = train_ds  # Your dataset here

# Create an iterator for the dataset
iterator = dataset.make_one_shot_iterator()

# Get the next element from the iterator
next_element = iterator.get_next()

# Create a TensorFlow session
with tf.Session() as sess:
    try:
        while True:
            # Fetch and print the next element from the dataset
            element = sess.run(next_element)
            print(element)
    except tf.errors.OutOfRangeError:
        # This exception will be raised when all elements have been iterated through
        pass

# %%
dataset = train_ds  # Your dataset here

# Create an iterator for the dataset
iterator = dataset.make_one_shot_iterator()

# Get the next element from the iterator
next_element = iterator.get_next()

# Create a TensorFlow session
with tf.Session() as sess:
    try:
        while True:
            # Fetch and print the next element from the dataset
            element = sess.run(next_element)
            print(element)
    except tf.errors.OutOfRangeError:
        # This exception will be raised when all elements have been iterated through
        pass

# %%
encoded,inputs = encoded_features(train_ds)
